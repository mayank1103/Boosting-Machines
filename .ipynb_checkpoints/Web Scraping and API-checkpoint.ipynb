# %% [markdown]
# ### using urllib to read html data from webpages

# %%
from urllib.request import urlopen
x = urlopen('https://www.bbc.co.uk/')
k=x.read()

# %%
k
# Out:
# b'<!DOCTYPE html>\n<!--[if lte IE 9]>\n  <html lang="en-GB" class="no-js no-flexbox no-flexboxlegacy">\n<![endif]-->\n<!--[if gt IE 9]><!-->\n  <html lang="en-GB" class="no-js">\n<!--<![endif]-->\n<head>\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><script type="text/javascript">\n      var _sf_startpt = (new Date()).getTime();\n    </script><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="The best of the BBC, with the latest news and sport headlines, weather, TV &amp; radio highlights and much more from across the whole of BBC Online" name="description"><meta content="BBC, British Broadcasting Corporation, BBCi, News, Sport, iPlayer, TV, Radio, Food, Music, Business, Arts, Bitesize, Lifestyle, Entertainment, Headlines" name="keywords"><meta property="og:title" content="BBC - Home"><meta property="og:type" content="website"><meta property="og:description" content="The best of the BBC, with the latest news and sport headlines, weather, TV &amp; radio highlights and much more from across the whole of BBC Online"><meta property="og:site_name" content="BBC Homepage"><meta property="og:locale" content="en_GB"><meta property="article:author" content="https://www.facebook.com/bbc"><meta property="og:article:section" content="Home"><meta property="og:url" content="http://www.bbc.co.uk"><meta property="og:image" content="//homepage.files.bbci.co.uk/s/homepage-v5/2640/images/bbc_homepage.png"><meta name="twitter:card" content="summary_large_image"><meta name="twitter:site" content="@bbccouk"><meta name="twitter:title" content="BBC - Home"><meta name="twitter:description" content="The best of the BBC, with the latest news and sport headlines, weather, TV &amp; radio highlights and much more from across the whole of BBC Online"><meta name="twitter:creator" content="@bbccouk"><meta name="twitter:image:src" content="//homepage.files.bbci.co.uk/s/homepage-v5/2640/images/bbc_homepage.png"><meta name="twitter:image:alt" content="BBC Homepage"><meta name="twitter:domain" content="www.bbc.co.uk"><link rel="canonical" href="https://www.bbc.co.uk" /><script type="text/javascript">(function () {if (window.location.pathname === \'/\') { window.bbcredirection = { geo: true }; }})();</script><!-- Nav Env: live -->\n<!-- Analytics Web Module: 95 -->\n<!-- NavID Web Module: 0.2.0-169 -->\n<!-- Searchbox Web Module: 137 -->\n<!-- Promo Web Module: 2.0.0-19.a2716e4 -->\n<meta name="viewport" content="width=device-width, initial-scale=1.0"><meta property="fb:admins" content="100004154058350"><link rel="stylesheet" href="https://nav.files.bbci.co.uk/orbit/2.0.0-237.75bdb4e/css/orb-ltr.min.css"><!--[if (lt IE 9) & (!IEMobile)]>\n    <link rel="stylesheet" href="https://nav.files.bbci.co.uk/orbit/2.0.0-237.75bdb4e/css/orb-ie-ltr.min.css">\n    <![endif]--><script type="text/javascript">/*<![CDATA[*/\n        window.orb = {\n            lang: \'en\',\n            bbcBaseUrl: \'http://www.bbc.co.uk\',\n            bbcUrlPrefix: \'http://www.\',\n            staticHost: \'https://nav.files.bbci.co.uk/orbit/2.0.0-237.75bdb4e\',\n            figUrl: \'https://fig.bbc.co.uk/frameworks/fig/2/fig.js\',\n            partialCookieOvenUrl: \'https://cookie-oven.api.bbc\'\n        };\n\n        document.documentElement.className += (document.documentElement.className? \' \' : \'\') + \'orb-js\';\n        window.orb.worldwideNavlinks = \'<li class="orb-nav-home"><a href="http://www.bbc.com/">Home</a></li><li class="orb-nav-newsdotcom"><a href="https://www.bbc.com/news">News</a></li><li class="orb-nav-sport"><a href="https://www.bbc.com/sport">Sport</a></li><li class="orb-nav-weather"><a href="https://www.bbc.com/weather">Weather</a></li><li class="orb-nav-shop"><a href="http://shop.bbc.com/">Shop</a></li><li class="orb-nav-earthdotcom"><a href="http://www.bbc.com/earth/">Earth</a></li><li class="orb-nav-travel-dotcom"><a href="http://www.bbc.com/travel/">Travel</a></li><li class="orb-nav-capital"><a href="http://www. ...

# %%
parts=str(k).split("<a href=")

# %%
parts[1:5]
# Out:
# ['"https://www.bbc.com/">Home</a></li><li class="orb-nav-newsdotcom">',
#  '"https://www.bbc.com/news">News</a></li><li class="orb-nav-sport">',
#  '"https://www.bbc.com/sport">Sport</a></li><li class="orb-nav-reeldotcom">',
#  '"https://www.bbc.com/reel">Reel</a></li><li class="orb-nav-worklife">']

# %%
for part in parts[1:5]:
    print(part.split('"')[1])
# Out:
# https://www.bbc.com/
# https://www.bbc.com/news
# https://www.bbc.com/sport
# https://www.bbc.com/reel

# %%
in_links=[]
parts=str(k).split("<a href=")
for part in parts:
    link=part.split('"')[1]
    if "www.bbc" not in link:pass
    else:
        in_links.append(link)
in_links
# Out:
# ['https://www.bbc.com/',
#  'https://www.bbc.com/news',
#  'https://www.bbc.com/sport',
#  'https://www.bbc.com/reel',
#  'https://www.bbc.com/worklife',
#  'https://www.bbc.com/travel',
#  'https://www.bbc.com/future',
#  'https://www.bbc.com/culture',
#  'https://www.bbc.com/culture/music',
#  'https://www.bbc.co.uk/schedules/p00fzl9m',
#  'https://www.bbc.com/weather',
#  'https://www.bbc.co.uk/sounds',
#  'https://www.bbc.co.uk',
#  'https://www.bbc.co.uk',
#  'https://www.bbc.co.uk/news',
#  'https://www.bbc.co.uk/sport',
#  'https://www.bbc.co.uk/weather',
#  'https://www.bbc.co.uk/iplayer',
#  'https://www.bbc.co.uk/sounds',
#  'https://www.bbc.co.uk/cbbc',
#  'https://www.bbc.co.uk/cbeebies',
#  'https://www.bbc.co.uk/food',
#  'https://www.bbc.co.uk/bitesize',
#  'https://www.bbc.co.uk/arts',
#  'https://www.bbc.co.uk/taster',
#  'https://www.bbc.co.uk/news/localnews',
#  'https://www.bbc.co.uk/tv',
#  'https://www.bbc.co.uk/radio',
#  'https://www.bbc.co.uk/bbcthree',
#  'https://www.bbc.co.uk/sport/live/rugby-league/49829401',
#  'https://www.bbc.co.uk/news/business-50267454',
#  'https://www.bbc.co.uk/programmes/articles/k5Z37txbhKZqK2NTQ3j7wS/12-guests-we-ve-loved-on-zoe-ball-this-autumn',
#  'https://www.bbc.co.uk/news/entertainment-arts-48186376',
#  'https://www.bbc.co.uk/news/science-environment-50264797',
#  'https://www.bbc.co.uk/programmes/p07sq5nn',
#  'https://www.bbc.co.uk/news/business-50267454',
#  'https://www.bbc.co.uk/news/uk-england-50262597',
#  'https://www.bbc.co.uk/news/science-environment-50264797',
#  'https://www.bbc.co.uk/sport/live/football/49990270',
#  'https://www.bbc.co.uk/sport/rugby-union/50261748',
#  'https://www.bbc.co.uk/sport/formula1/50269690',
#  'https://www.bbc.co.uk/news/uk-england-birmingham-50264167',
#  'https://www.bbc.co.uk/programmes/articles/k5Z37txbhKZqK2NTQ3j7wS/12-guests-we-ve-loved-on-zoe-ball-this-autumn',
#  'https://www.bbc.co.uk/cbbc/quizzes/blue-peter-badge-attraction-finder-quiz',
#  'https://www.bbc.co.uk/sport/football/50225585',
#  'https://www.bbc.co.uk/sport/rugby-union/50259687',
#  'https://www.bbc.co.uk/sport/boxing/50257144',
#  'https://www.bbc.co.uk/sport/horse-racing/50247329',
#  'https://www.bbc.co.uk/programmes/p07sn023',
#  'https://www.bbc.co.uk/news/av/stories-50161306/how-i-cleared-my-20k-debt',
#  'https://www.bbc.com/scotland',
#  'https://www.bbc.com/alba',
#  'https://www.bbc.com/wales',
#  'https://www.bbc.com/cymru',
#  'https://www.bbc.com/northernireland',
#  'https://www.bbc.co.uk/news/uk-politics-50265137',
#  'https://www.bbc.co.uk/news/entertainment-arts-50254906',
#  'https://www.bbc.co.uk/news/newsbeat-50261297',
#  'https://www.bbc.co.uk/news/newsbeat-50222405',
#  'https://www.bbc.co.uk/mediacentre/latestnews/2019/normal-people-first-look',
#  'https://www.bbc.co.uk/newsround/50245879',
#  'https://www.bbc.co.uk/iplayer/episode/m0009tt8',
#  'https://www.bbc.co.uk/iplayer/episode/p07l5qvv',
#  'https://www.bbc.co.uk/iplayer/episode/m0009fhr',
#  'https://www.bbc.co.uk/iplayer/episode/p07pg6z9',
#  'https://www.bbc.co.uk/iplayer/episode/m0008zsd',
#  'https://www.bbc.co.uk/iplayer/episode/p06nfv60',
#  'https://www.bbc.co.uk/programmes/p07smd8j',
#  'https://www.bbc.co.uk/cbeebies/grownups/9-annoying-things-kids-do-with-your-devices',
#  'https://www.bbc.co.uk/blogs/natureuk/entries/f1778100-648d-4330-baf6-f6d596f87504',
#  'https://www.bbc.co.uk/programmes/articles/5kB70cXXBR9GXl6L4vj7fwl/the-tough-talking-gp-who-leaves-shocked-patients-laid-bare',
#  'https://www.bbc.co.uk/news/world-us-canada-50007566',
#  'https://www.bbc.co.uk/news/business-50236702',
#  'https://www.bbc.co.uk/news/uk-politics-50256887',
#  'https://www.bbc.co.uk/news/uk-politics-50252635',
#  'https://www.bbc.co.uk/news/world-asia-50266947',
#  'https://www.bbc.co.uk/programmes/p07sqvx0',
#  'https://www.bbc.co.uk/bitesize/articles/zmh4bdm',
#  'https://www.bbc.co.uk/news/av/stories-50123587/how-money-laundering-works',
#  'https://www.bbc.co.uk/news/world-europe-50268864',
#  'https://www.bbc.co.uk/news/uk-england-suffolk-50262667',
#  'https://www.bbc.co.uk/news/in-pictures-49843810',
#  'https://www.bbc.co.uk/sounds/play/w3csyx0j',
#  'https://www.bbc.co.uk/newsround/50231684',
#  'https://www.bbc.co.uk/news/uk-50226575',
#  'https://www.bbc.co.uk/food/recipes/bangbangchicken_82544',
#  'https://www.bbc.co.uk/food/enchiladas',
#  'https://www.bbc.co.uk/food/collections/spicy_soups',
#  'https://www.bbc.co.uk/news/entertainment-arts-50235905',
#  'https://www.bbc.co.uk/iplayer/episode/p07sgm6t',
#  'https://www.bbc.co.uk/programmes/p07shh2l',
#  'https://www.bbc.co.uk/news/world-australia-50257903',
#  'https://www.bbc.co.uk/news/newsbeat-50218990',
#  'https://www.bbc.co.uk/news/business-50172337',
#  'https://www.bbc.co.uk/news/world-50207811',
#  'https://www.bbc.co.uk/cbbc/quizzes/spot-the-ball-road-to-rugby-world-cup-final',
#  'https://www.bbc.co.uk/sport/football/50186608',
#  'http://www.bbc.com/scotland',
#  'http://www.bbc.com/alba',
#  'http://www.bbc.com/wales',
#  'http://www.bbc.com/cymru',
#  'http://www.bbc.com/northernireland',
#  'http://www.bbc.co.uk/complaints/',
#  'https://www.bbc.co.uk',
#  'https://www.bbc.co.uk/news',
#  'https://www.bbc.co.uk/sport',
#  'https://www.bbc.co.uk/weather',
#  'https://www.bbc.co.uk/iplayer',
#  'https://www.bbc.co.uk/sounds',
#  'https://www.bbc.co.uk/cbbc',
#  'https://www.bbc.co.uk/cbeebies',
#  'https://www.bbc.co.uk/food',
#  'https://www.bbc.co.uk/bitesize',
#  'https://www.bbc.co.uk/arts',
#  'https://www.bbc.co.uk/taster',
#  'https://www.bbc.co.uk/news/localnews',
#  'https://www.bbc.co.uk/tv',
#  'https://www.bbc.co.uk/radio',
#  'https://www.bbc.co.uk/bbcthree',
#  'https://www.bbc.com/usingthebbc/cookies/how-does-the-bbc-use-cookies-for-advertising/',
#  'https://www.bbc.co.uk/usingthebbc/terms/',
#  'https://www.bbc.co.uk/aboutthebbc',
#  'https://www.bbc.co.uk/usingthebbc/privacy/',
#  'https://www.bbc.co.uk/usingthebbc/cookies/',
#  'https://www.bbc.co.uk/accessibility/',
#  'https://www.bbc.co.uk/guidance',
#  'https://www.bbc.co.uk/contact',
#  'https://www.bbc.co.uk/bbcnewsletter',
#  'https://www.bbc.co.uk/help/web/links/']

# %%
len(in_links)
# Out:
# 129

# %%
in_links=set(in_links)
len(in_links)
# Out:
# 108

# %% [markdown]
# ### Accessing google search with urllib

# %%
url='https://www.google.com/search?q=python+programming+tutorials'
resp = urlopen(url)
respData = resp.read()
print(respData) #error should come here because google doesnt provide access to such coding
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-10-def9af159282> in <module>()
#       1 url='https://www.google.com/search?q=python+programming+tutorials'
# ----> 2 resp = urlopen(url)
#       3 respData = resp.read()
#       4 print(respData)
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %%
from urllib.request import Request
url = 'https://www.google.com/search?q=python+programming+tutorials'

headers = {}
headers['User-Agent'] = r"Mozilla/5.0 (X11; Linux i686) AppleWebKit/537.17 (KHTML, like Gecko) Chrome/24.0.1312.27 Safari/537.17"

req = Request(url, headers = headers)
resp = urlopen(req)
respData = resp.read()

# %%
print(respData)
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en-IN"><head><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><meta content="origin" name="referrer"><title>python programming tutorials - Google Search</title><script nonce="WomRUU2sX7tAAimnZ8iywA==">(function(){window.google={kEI:\'8xm9XZTPEtSx5OUPx8qYcA\',kEXPI:\'31\',authuser:0,kscs:\'c9c918f0_8xm9XZTPEtSx5OUPx8qYcA\',kGL:\'IN\',kBL:\'9bc9\'};google.sn=\'web\';google.kHL=\'en-IN\';google.jsfs=\'Ffpdje\';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||google.kEI};google.getLEI=function(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b};google.https=function(){return"https:"==window.location.protocol};google.ml=function(){return null};google.time=function(){return(new Date).getTime()};google.log=function(a,b,e,c,g){if(a=google.logUrl(a,b,e,c,g)){b=new Image;var d=google.lc,f=google.li;d[f]=b;b.onerror=b.onload=b.onabort=function(){delete d[f]};google.vel&&google.vel.lu&&google.vel.lu(a);b.src=a;google.li=f+1}};google.logUrl=function(a,b,e,c,g){var d="",f=google.ls||"";e||-1!=b.search("&ei=")||(d="&ei="+google.getEI(c),-1==b.search("&lei=")&&(c=google.getLEI(c))&&(d+="&lei="+c));c="";!e&&google.cshid&&-1==b.search("&cshid=")&&"slh"!=a&&(c="&cshid="+google.cshid);a=e||"/"+(g||"gen_204")+"?atyp=i&ct="+a+"&cad="+b+d+f+"&zx="+google.time()+c;/^http:/i.test(a)&&google.https()&&(google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a};}).call(this);(function(){google.y={};google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};}).call(this);google.f={};(function(){google.hs={h:true,sie:false};})();var k="function"==typeof Object.defineProperties?Object.defineProperty:function(a,e,c){a!=Array.prototype&&a!=Object.prototype&&(a[e]=c.value)},l="undefined"!=typeof window&&window===this?this:"undefined"!=typeof global&&null!=global?global:this,m=function(a,e){if(e){for(var c=l,b=a.split("."),f=0;f<b.length-1;f++){var d=b[f];d in c||(c[d]={});c=c[d]}b=b[b.length-1];f=c[b];d=e(f);d!=f&&null!=d&&k(c,b,{configurable:!0,writable:!0,value:d})}};m("String.prototype.startsWith",function(a){return a?a:function(e,c){if(null==this)throw new TypeError("The \'this\' value for String.prototype.startsWith must not be null or undefined");if(e instanceof RegExp)throw new TypeError("First argument to String.prototype.startsWith must not be a regular expression");var b=this+"";e+="";for(var f=b.length,d=e.length,h=Math.max(0,Math.min(c|0,b.length)),g=0;g<d&&h<f;)if(b[h++]!=e[g++])return!1;return g>=d}});google.arwt=function(a){a.href=document.getElementById(a.id.substring(a.id.startsWith("vcs")?3:1)).href;return!0};(function(){var g=this||self,h=Date.now||function(){return+new Date};var u={};var w=function(b,d){if(null===d)return!1;if("contains"in b&&1==d.nodeType)return b.contains(d);if("compareDocumentPosition"in b)return b==d||!!(b.compareDocumentPosition(d)&16);for(;d&&b!=d;)d=d.parentNode;return d==b};var x=function(b,d){return function(a){a||(a=window.event);return d.call(b,a)}},C=function(b){b=b.target||b.srcElement;!b.getAttribute&&b.parentNode&&(b=b.parentNode);return b},D="undefined"!=typeof navigator&&/Macintosh/.test(navigator.userAgent),E="undefined"!=typeof navigator&&!/Opera/.test(navigator.userAgent)&&/WebKit/.test(navigator.userAgent),aa={A:1,INPUT:1,TEXTAREA:1,SELECT:1,BUTTON:1},ba=function(){this._mouseEventsPrevented=!0},F={A:13,BUTTON:0,CHECKBOX:32,COMBOBOX:13,FILE:0,GRIDCELL:13,LINK:13,LISTBOX:13,MENU:0,MENUBAR:0,MENUITEM:0,MENUITEMCHECKBOX:0,MENUITEMRADIO:0,OPTION:0,RADIO:32,RADIOGROUP:32,RESET:0,SUBMIT:0,SWITCH:32,TA ...

# %% [markdown]
# ### Parsing with BeautifulSoup

# %%
from bs4 import BeautifulSoup

# %%
mydata=urlopen("https://in.finance.yahoo.com/q?s=SBIN.BO").read()
soup = BeautifulSoup(mydata,'lxml')

# %%
soup.findAll("a")
# Out:
# [<a class="Bgpx(0) Bgr(nr) Cur(p) D(b) H(35px) Bgz(702px) Mx(a)! W(92px)" data-reactid="12" href="https://in.finance.yahoo.com/" id="uh-logo"><b class="Hidden" data-reactid="13">Yahoo</b></a>,
#  <a class="Pos(r) D(ib) Ta(s) Td(n):h" data-reactid="45" href="https://mail.yahoo.com/?.intl=in&amp;.lang=en-IN&amp;.partner=none&amp;.src=finance" id="uh-mail"><svg class="Cur(p)" data-icon="NavMail" data-reactid="46" height="35" style="fill:#400090;stroke:#400090;stroke-width:0;vertical-align:bottom;" viewbox="0 0 512 512" width="30"><path d="M460.586 91.31H51.504c-10.738 0-19.46 8.72-19.46 19.477v40.088l224 104.03 224-104.03v-40.088c0-10.757-8.702-19.478-19.458-19.478M32.046 193.426V402.96c0 10.758 8.72 19.48 19.458 19.48h409.082c10.756 0 19.46-8.722 19.46-19.48V193.428l-224 102.327-224-102.327z" data-reactid="47"></path></svg><b class="Lh(userNavTextLh) D(ib) C($c-fuji-purple-1-c) Fz(14px) Fw(b) Va(t) Mstart(6px)" data-reactid="48">Mail</b></a>,
#  <a class="Lh(50px) Ta(c) Bdbw(3px) Bdbs(s) Px(12px) C($linkColor) Bdbc($seperatorColor) D(b) Td(n) selected_Bdbc($linkColor) selected_C(black) selected_Bgc($navSelectedBlue) " data-reactid="7" href="/quote/SBIN.BO?p=SBIN.BO"><!-- react-text: 8 --><!-- /react-text --><span data-reactid="9">Summary</span></a>,
#  <a class="Lh(50px) Ta(c) Bdbw(3px) Bdbs(s) Px(12px) C($linkColor) Bdbc($seperatorColor) D(b) Td(n) selected_Bdbc($linkColor) selected_C(black) selected_Bgc($navSelectedBlue) " data-reactid="11" href="/quote/SBIN.BO/key-statistics?p=SBIN.BO"><!-- react-text: 12 --><!-- /react-text --><span data-reactid="13">Statistics</span></a>,
#  <a class="Lh(50px) Ta(c) Bdbw(3px) Bdbs(s) Px(12px) C($linkColor) Bdbc($seperatorColor) D(b) Td(n) selected_Bdbc($linkColor) selected_C(black) selected_Bgc($navSelectedBlue) " data-reactid="15" href="/quote/SBIN.BO/history?p=SBIN.BO"><!-- react-text: 16 --><!-- /react-text --><span data-reactid="17">Historical data</span></a>,
#  <a class="Lh(50px) Ta(c) Bdbw(3px) Bdbs(s) Px(12px) C($linkColor) Bdbc($seperatorColor) D(b) Td(n) selected_Bdbc($linkColor) selected_C(black) selected_Bgc($navSelectedBlue) " data-reactid="19" href="/quote/SBIN.BO/profile?p=SBIN.BO"><!-- react-text: 20 --><!-- /react-text --><span data-reactid="21">Profile</span></a>,
#  <a class="Lh(50px) Ta(c) Bdbw(3px) Bdbs(s) Px(12px) C($linkColor) Bdbc($seperatorColor) D(b) Td(n) selected_Bdbc($linkColor) selected_C(black) selected_Bgc($navSelectedBlue) " data-reactid="23" href="/quote/SBIN.BO/financials?p=SBIN.BO"><!-- react-text: 24 --><!-- /react-text --><span data-reactid="25">Financials</span><img alt="new" class="H(13px) W(25px) Mstart(5px) Va(m)" data-reactid="26" src="https://s.yimg.com/uc/New.png"/></a>,
#  <a class="Lh(50px) Ta(c) Bdbw(3px) Bdbs(s) Px(12px) C($linkColor) Bdbc($seperatorColor) D(b) Td(n) selected_Bdbc($linkColor) selected_C(black) selected_Bgc($navSelectedBlue) " data-reactid="28" href="/quote/SBIN.BO/analysis?p=SBIN.BO"><!-- react-text: 29 --><!-- /react-text --><span data-reactid="30">Analysis</span></a>,
#  <a class="Lh(50px) Ta(c) Bdbw(3px) Bdbs(s) Px(12px) C($linkColor) Bdbc($seperatorColor) D(b) Td(n) selected_Bdbc($linkColor) selected_C(black) selected_Bgc($navSelectedBlue) " data-reactid="32" href="/quote/SBIN.BO/options?p=SBIN.BO"><!-- react-text: 33 --><!-- /react-text --><span data-reactid="34">Options</span></a>,
#  <a class="Lh(50px) Ta(c) Bdbw(3px) Bdbs(s) Px(12px) C($linkColor) Bdbc($seperatorColor) D(b) Td(n) selected_Bdbc($linkColor) selected_C(black) selected_Bgc($navSelectedBlue) " data-reactid="36" href="/quote/SBIN.BO/holders?p=SBIN.BO"><!-- react-text: 37 --><!-- /react-text --><span data-reactid="38">Holders</span></a>,
#  <a class="Lh(50px) Ta(c) Bdbw(3px) Bdbs(s) Px(12px) C($linkColor) Bdbc($seperatorColor) D(b) Td(n) selected_Bdbc($linkColor) selected_C(black) selected_Bgc($navSelectedBlue) " data-reactid="40" href="/quote/SBIN.BO/sustainability?p=SBIN.BO"><!-- react-text: 41 --><!-- /react-text --><span data-reactid="42">Sustainability</span></a>,
#  <a class="Mend(10px) P(0px) M(0px) C($linkColor) C($primaryColor):h Bd(0px) O(n)" data-reactid="7" href="/quote/SBIN.BO/news?p=SBIN.BO"><div class="Fw(500) D(ib) Pend(10px) H(18px) BdEnd Bdc($seperatorColor)" data-reactid="8"><span data-reactid="9">News</span></div></a>,
#  <a class="Mend(10px) P(0px) M(0px) C($linkColor) C($primaryColor):h Bd(0px) O(n)" data-reactid="10" href="/quote/SBIN.BO/press-releases?p=SBIN.BO"><div class="Fw(500) D(ib) Pend(10px) H(18px)" data-reactid="11"><span data-reactid="12">Press Releases</span></div></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="13" href="/news/indian-shares-rise-special-muhurat-154020430.html"><u class="StretchedBox" data-reactid="14"></u><!-- react-text: 15 -->Indian shares rise in special 'muhurat' session on Diwali<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="26" href="/news/state-bank-india-profit-triples-091717253.html"><u class="StretchedBox" data-reactid="27"></u><!-- react-text: 28 -->SBI profit beats on higher interest income, better asset quality<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="39" href="/news/sbis-credit-card-business-aims-113627485.html"><u class="StretchedBox" data-reactid="40"></u><!-- react-text: 41 -->SBI's credit card business aims to raise $1.1 billion via IPO: source<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="52" href="/news/state-bank-india-cuts-benchmark-082101757.html"><u class="StretchedBox" data-reactid="53"></u><!-- react-text: 54 -->State Bank of India cuts benchmark lending rates by 15 bps<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="62" href="/news/state-bank-india-seeks-bids-071022814.html"><u class="StretchedBox" data-reactid="63"></u><!-- react-text: 64 -->State Bank of India seeks bids for Videocon's overseas oil, gas assets<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="75" href="/news/sbi-posts-profit-first-quarter-083245260.html"><u class="StretchedBox" data-reactid="76"></u><!-- react-text: 77 -->State Bank of India warns of muted credit growth, misses quarterly profit estimates<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="88" href="/news/exclusive-sbi-tightens-lending-terms-175533859.html"><u class="StretchedBox" data-reactid="89"></u><!-- react-text: 90 -->Exclusive: SBI tightens lending terms for auto dealers - source, internal memo<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="101" href="/news/exclusive-indias-sbi-tightens-lending-175450256.html"><u class="StretchedBox" data-reactid="102"></u><!-- react-text: 103 -->Exclusive: India's SBI tightens lending terms for auto dealers - source, internal memo<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="114" href="/news/sbi-cuts-deposit-rates-keeps-104228583.html"><u class="StretchedBox" data-reactid="115"></u><!-- react-text: 116 -->SBI cuts deposit rates, keeps lending rates unchanged<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="127" href="/news/jet-airways-lenders-approve-interim-142019586.html"><u class="StretchedBox" data-reactid="128"></u><!-- react-text: 129 -->Jet Airways' lenders approve interim finance plan for the carrier<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="140" href="/news/lenders-bankrupt-jet-airways-attempt-025917265.html"><u class="StretchedBox" data-reactid="141"></u><!-- react-text: 142 -->Lenders of bankrupt Jet Airways to attempt to sell carrier again<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="153" href="/news/wilful-defaults-india-cross-21-131914303.html"><u class="StretchedBox" data-reactid="154"></u><!-- react-text: 155 -->Wilful defaults in India cross $21 billion in 2018-19<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="166" href="/news/nclt-admits-insolvency-plea-against-134437326.html"><u class="StretchedBox" data-reactid="167"></u><!-- react-text: 168 -->NCLT admits insolvency plea against Jet Airways<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="179" href="/news/nifty-sensex-edge-lower-over-050958387.html"><u class="StretchedBox" data-reactid="180"></u><!-- react-text: 181 -->Nifty, Sensex end weaker amid global slowdown worries<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="192" href="/news/jet-airways-slumps-reports-etihads-044735809.html"><u class="StretchedBox" data-reactid="193"></u><!-- react-text: 194 -->Jet Airways slumps after reports of Etihad's non-binding offer<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="205" href="/news/state-bank-india-says-two-095227463.html"><u class="StretchedBox" data-reactid="206"></u><!-- react-text: 207 -->Etihad submits bid for Jet Airways, eyes minority stake<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="218" href="/news/state-bank-india-gets-sealed-142812373.html"><u class="StretchedBox" data-reactid="219"></u><!-- react-text: 220 -->State Bank of India gets sealed bid for Jet Airways from Etihad<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="228" href="/news/state-bank-india-turns-profit-083353157.html"><u class="StretchedBox" data-reactid="229"></u><!-- react-text: 230 -->SBI misses fourth-quarter profit estimate, provisions up quarter-on-quarter<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="238" href="/m/730e15e2-c699-3918-b5a0-169ab2239590/ss_don%26%2339%3Bt-blame-state-banks.html" target="_self"><u class="StretchedBox" data-reactid="239"></u><!-- react-text: 240 -->Don't blame state banks for weakness in India's economy, says the country's largest lender<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="251" href="/m/cec40fb6-0b5b-3b15-b2ce-71581ece6c6a/ss_jet-airways%26%2339%3B-lenders-hope.html" target="_self"><u class="StretchedBox" data-reactid="252"></u><!-- react-text: 253 -->Jet Airways' lenders hope bidding process can save airline<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="261" href="/news/timeline-jet-airways-joy-flying-151825293.html"><u class="StretchedBox" data-reactid="262"></u><!-- react-text: 263 -->Timeline: Jet Airways - How the 'Joy of Flying' airline's dreams soured<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="271" href="/m/77145535-3235-3f26-98b6-13fc79fd9922/ss_jet-airways-stock-suffers.html" target="_self"><u class="StretchedBox" data-reactid="272"></u><!-- react-text: 273 -->Jet Airways stock suffers heavy losses after emergency funding doubts<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="281" href="/m/8ed0cc96-18ee-3b60-9d01-ede17fc37b07/ss_india%26%2339%3Bs-jet-airways.html" target="_self"><u class="StretchedBox" data-reactid="282"></u><!-- react-text: 283 -->India's Jet Airways cancels all international flights as debt problems deepen<!-- /react-text --></a>,
#  <a class="nr-applet-nav-item Td(n) rapidnofollow Ell Td(n) D(ib) Lh(itemHeight_uhMagDesign) Tt(c)! Bdbc($c-fuji-blue-1-a):h Bdbs(s):h Bdbw(4px):h H(38px) Trstf(l) Trsde(0s) Trsdu(.18s) Trsp(border-bottom-width) C(darkTheme)" data-reactid="9" href="/" title="Finance"><!-- react-text: 10 -->Finance<!-- /react-text --></a>,
#  <a class="nr-applet-nav-item Td(n) rapidnofollow nr-list-link Ell Td(n) D(ib) Bdbs(s):h Pos(r) Bdc($fg-header) Lh(cateNavHeight) C(hoverColor):h Tt(n)! C($fg-header) Mt(cateNavMargin) C(darkTheme) Bdc(darkTheme) Tt(c) Fz(14px) openSubNav" data-reactid="17" href="/watchlists" role="listitem link" title="Watchlists"><!-- react-text: 18 -->Watchlists<!-- /react-text --></a>,
#  <a class="nr-applet-nav-item Td(n) rapidnofollow nr-list-link Ell Td(n) D(ib) Bdbs(s):h Pos(r) Bdc($fg-header) Lh(cateNavHeight) C(hoverColor):h Tt(n)! C($fg-header) Mt(cateNavMargin) C(darkTheme) Bdc(darkTheme) Tt(c) Fz(14px) openSubNav" data-reactid="20" href="/budget" role="listitem link" title="Budget 2019"><!-- react-text: 21 -->Budget 2019<!-- /react-text --></a>,
#  <a class="nr-applet-nav-item Td(n) rapidnofollow nr-list-link Ell Td(n) D(ib) Bdbs(s):h Pos(r) Bdc($fg-header) Lh(cateNavHeight) C(hoverColor):h Tt(n)! C($fg-header) Mt(cateNavMargin) C(darkTheme) Bdc(darkTheme) Tt(c) Fz(14px) openSubNav" data-reactid="23" href="/portfolios" role="listitem link" title="My Portfolio"><!-- react-text: 24 -->My Portfolio<!-- /react-text --></a>,
#  <a class="nr-applet-nav-item Td(n) rapidnofollow nr-list-link Ell Td(n) D(ib) Bdbs(s):h Pos(r) Bdc($fg-header) Lh(cateNavHeight) C(hoverColor):h Tt(n)! C($fg-header) Mt(cateNavMargin) C(darkTheme) Bdc(darkTheme) Tt(c) Fz(14px) openSubNav" data-reactid="26" href="/personal-finance" role="listitem link" title="Personal Finance"><!-- react-text: 27 -->Personal Finance<!-- /react-text --></a>,
#  <a class="nr-applet-nav-item Td(n) rapidnofollow nr-list-link Ell Td(n) D(ib) Bdbs(s):h Pos(r) Bdc($fg-header) Lh(cateNavHeight) C(hoverColor):h Tt(n)! C($fg-header) Mt(cateNavMargin) C(darkTheme) Bdc(darkTheme) Tt(c) Fz(14px) openSubNav" data-reactid="29" href="/topic/tech" role="listitem link" title="Technology"><!-- react-text: 30 -->Technology<!-- /react-text --></a>,
#  <a class="nr-applet-nav-item Td(n) rapidnofollow nr-list-link Ell Td(n) D(ib) Bdbs(s):h Pos(r) Bdc($fg-header) Lh(cateNavHeight) C(hoverColor):h Tt(n)! C($fg-header) Mt(cateNavMargin) C(darkTheme) Bdc(darkTheme) Tt(c) Fz(14px) openSubNav" data-reactid="32" href="/topic/autos" role="listitem link" title="Autos"><!-- react-text: 33 -->Autos<!-- /react-text --></a>,
#  <a class="nr-applet-nav-item Td(n) rapidnofollow nr-list-link Ell Td(n) D(ib) Bdbs(s):h Pos(r) Bdc($fg-header) Lh(cateNavHeight) C(hoverColor):h Tt(n)! C($fg-header) Mt(cateNavMargin) C(darkTheme) Bdc(darkTheme) Tt(c) Fz(14px) openSubNav" data-reactid="38" href="/topic/latestnews" role="listitem link" title="News"><!-- react-text: 39 -->News<!-- /react-text --></a>,
#  <a class="nr-applet-nav-item Td(n) rapidnofollow nr-list-link Ell Td(n) D(ib) Bdbs(s):h Pos(r) Bdc($fg-header) Lh(cateNavHeight) C(hoverColor):h Tt(n)! C($fg-header) Mt(cateNavMargin) C(darkTheme) Bdc(darkTheme) Tt(c) Fz(14px) openSubNav" data-reactid="41" href="/topic/videos" role="listitem link" title="Videos"><!-- react-text: 42 -->Videos<!-- /react-text --></a>]

# %%
all_links=soup.findAll("a")
for elem in all_links:
    link=str(elem.get('href'))
    print(link)
# Out:
# https://in.finance.yahoo.com/
# https://mail.yahoo.com/?.intl=in&.lang=en-IN&.partner=none&.src=finance
# /quote/SBIN.BO?p=SBIN.BO
# /quote/SBIN.BO/key-statistics?p=SBIN.BO
# /quote/SBIN.BO/history?p=SBIN.BO
# /quote/SBIN.BO/profile?p=SBIN.BO
# /quote/SBIN.BO/financials?p=SBIN.BO
# /quote/SBIN.BO/analysis?p=SBIN.BO
# /quote/SBIN.BO/options?p=SBIN.BO
# /quote/SBIN.BO/holders?p=SBIN.BO
# /quote/SBIN.BO/sustainability?p=SBIN.BO
# /quote/SBIN.BO/news?p=SBIN.BO
# /quote/SBIN.BO/press-releases?p=SBIN.BO
# /news/indian-shares-rise-special-muhurat-154020430.html
# /news/state-bank-india-profit-triples-091717253.html
# /news/sbis-credit-card-business-aims-113627485.html
# /news/state-bank-india-cuts-benchmark-082101757.html
# /news/state-bank-india-seeks-bids-071022814.html
# /news/sbi-posts-profit-first-quarter-083245260.html
# /news/exclusive-sbi-tightens-lending-terms-175533859.html
# /news/exclusive-indias-sbi-tightens-lending-175450256.html
# /news/sbi-cuts-deposit-rates-keeps-104228583.html
# /news/jet-airways-lenders-approve-interim-142019586.html
# /news/lenders-bankrupt-jet-airways-attempt-025917265.html
# /news/wilful-defaults-india-cross-21-131914303.html
# /news/nclt-admits-insolvency-plea-against-134437326.html
# /news/nifty-sensex-edge-lower-over-050958387.html
# /news/jet-airways-slumps-reports-etihads-044735809.html
# /news/state-bank-india-says-two-095227463.html
# /news/state-bank-india-gets-sealed-142812373.html
# /news/state-bank-india-turns-profit-083353157.html
# /m/730e15e2-c699-3918-b5a0-169ab2239590/ss_don%26%2339%3Bt-blame-state-banks.html
# /m/cec40fb6-0b5b-3b15-b2ce-71581ece6c6a/ss_jet-airways%26%2339%3B-lenders-hope.html
# /news/timeline-jet-airways-joy-flying-151825293.html
# /m/77145535-3235-3f26-98b6-13fc79fd9922/ss_jet-airways-stock-suffers.html
# /m/8ed0cc96-18ee-3b60-9d01-ede17fc37b07/ss_india%26%2339%3Bs-jet-airways.html
# /
# /watchlists
# /budget
# /portfolios
# /personal-finance
# /topic/tech
# /topic/autos
# /topic/latestnews
# /topic/videos

# %%
len(soup.findAll('table'))
# Out:
# 2

# %%
mytable=soup.findAll('table')[0]
mytable.findAll('tr')
# Out:
# [<tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($seperatorColor) H(36px) " data-reactid="11"><td class="C($primaryColor) W(51%)" data-reactid="12"><span data-reactid="13">Previous close</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="14" data-test="PREV_CLOSE-value"><span class="Trsdu(0.3s) " data-reactid="15">312.25</span></td></tr>,
#  <tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($seperatorColor) H(36px) " data-reactid="16"><td class="C($primaryColor) W(51%)" data-reactid="17"><span data-reactid="18">Open</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="19" data-test="OPEN-value"><span class="Trsdu(0.3s) " data-reactid="20">312.80</span></td></tr>,
#  <tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($seperatorColor) H(36px) " data-reactid="21"><td class="C($primaryColor) W(51%)" data-reactid="22"><span data-reactid="23">Bid</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="24" data-test="BID-value"><span class="Trsdu(0.3s) " data-reactid="25">313.50 x 0</span></td></tr>,
#  <tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($seperatorColor) H(36px) " data-reactid="26"><td class="C($primaryColor) W(51%)" data-reactid="27"><span data-reactid="28">Ask</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="29" data-test="ASK-value"><span class="Trsdu(0.3s) " data-reactid="30">313.50 x 0</span></td></tr>,
#  <tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($seperatorColor) H(36px) " data-reactid="31"><td class="C($primaryColor) W(51%)" data-reactid="32"><span data-reactid="33">Day's range</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="34" data-test="DAYS_RANGE-value">308.70 - 315.10</td></tr>,
#  <tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($seperatorColor) H(36px) " data-reactid="35"><td class="C($primaryColor) W(51%)" data-reactid="36"><span data-reactid="37">52-week range</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="38" data-test="FIFTY_TWO_WK_RANGE-value">244.35 - 373.70</td></tr>,
#  <tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($seperatorColor) H(36px) " data-reactid="39"><td class="C($primaryColor) W(51%)" data-reactid="40"><span data-reactid="41">Volume</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="42" data-test="TD_VOLUME-value"><span class="Trsdu(0.3s) " data-reactid="43">2,137,459</span></td></tr>,
#  <tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($seperatorColor) H(36px) Bdbw(0)! " data-reactid="44"><td class="C($primaryColor) W(51%)" data-reactid="45"><span data-reactid="46">Avg. volume</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="47" data-test="AVERAGE_VOLUME_3MONTH-value"><span class="Trsdu(0.3s) " data-reactid="48">1,807,663</span></td></tr>]

# %%
for rows in mytable.findAll('tr'):
    data=rows.findAll('td')
    print_data=[]
    for d in data:
        print_data.append(d.text)
    print(print_data)
    #tr stands for tables.
    #td stands for cells.
# Out:
# ['Previous close', '312.25']
# ['Open', '312.80']
# ['Bid', '313.50 x 0']
# ['Ask', '313.50 x 0']
# ["Day's range", '308.70 - 315.10']
# ['52-week range', '244.35 - 373.70']
# ['Volume', '2,137,459']
# ['Avg. volume', '1,807,663']

# %% [markdown]
# # Twitter API

# %% [markdown]
# <ol>
# <li>Create a Twitter user account if you do not already have one. Make sure that you have added phone number to your account</li>
# <li>Go to https://apps.twitter.com/ and log in with your Twitter user account. This step gives you a Twitter dev account under the same name as your user account.</li>
# <li>Click “Create New App”</li>
# <li>Fill out the form, agree to the terms, and click “Create your Twitter application”</li>
# <li>In the next page, click on “Keys and Access Tokens” tab, and copy your “API key” and “API secret”. Scroll down and click “Create my access token”, and copy your “Access token” and “Access token secret”.</li>
# </ol>

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in c:\users\kvhb6535\appdata\local\continuum\anaconda3\lib\site-packages
# You are using pip version 9.0.1, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from twitter import Twitter, OAuth, TwitterHTTPError, TwitterStream

# %%
twitter_info_file="C:/Users/KVHB6535/Desktop/twitter_acc_info.txt"

f=open(twitter_info_file,"r")
mykeys=[]

for line in f:
    mykeys.append(line.split(':')[1].strip())
print(mykeys)
# Out:
# ['Soilw6vFtcn6pzStrYpfvCyG3', '9QtG2DUoJpIQdXcGK3JV0I823bHtqx0l3nnBl6NBOjoRpgki45', '805800713561391109-eqAIur9Vx5buda0sS8fXgpTgeXM2A84', 'j52UaUHlzyvCb89MFJ7HfiZ6NhlEefifcRKew0bhk58c3']

# %%
CONSUMER_KEY,CONSUMER_SECRET,ACCESS_TOKEN,ACCESS_SECRET=mykeys

# %% [markdown]
# you can very well manually assign values directly in the script instead of putting them in a file first

# %%
oauth = OAuth(ACCESS_TOKEN, ACCESS_SECRET, CONSUMER_KEY, CONSUMER_SECRET)
twitter= Twitter(auth=oauth)

# %%
# more details on the request parameters here :
# https://dev.twitter.com/rest/public/search
twitter.search.tweets(q='amritsar', result_type='recent', lang='en',
                      count=3)
#can we convert these json dumps to pandas dataframes

# %% [markdown]
# ### Twitter Stream

# %%
twitter_stream = TwitterStream(auth=oauth)

# %%
import json
iterator = twitter_stream.statuses.sample()

tweet_count = 10
for tweet in iterator:
    tweet_count -= 1
    
    print(json.dumps(tweet) )
       
    if tweet_count <= 0:
        break
# Out:
# {"delete": {"status": {"id": 1167121157465624577, "id_str": "1167121157465624577", "user_id": 1110212656370049031, "user_id_str": "1110212656370049031"}, "timestamp_ms": "1572677523022"}}
# {"delete": {"status": {"id": 1190466808748228608, "id_str": "1190466808748228608", "user_id": 1004589142313844736, "user_id_str": "1004589142313844736"}, "timestamp_ms": "1572677523453"}}
# {"created_at": "Sat Nov 02 06:52:03 +0000 2019", "id": 1190521938659041281, "id_str": "1190521938659041281", "text": "\u4ffa\u304c\u304a\u524d\u3092\u5acc\u3046\u308f\u3051\u306d\u3047\u304b\u3089\u2026", "source": "<a href=\"http://twittbot.net/\" rel=\"nofollow\">twittbot.net</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 952892462, "id_str": "952892462", "name": "\u693f\u4eac\u6c70", "screen_name": "TsubakiKyotabot", "location": null, "url": null, "description": "\u693f\u4eac\u6c70\u306e\u975e\u516c\u5f0f\u81ea\u52d5bot \u30d5\u30a9\u30ed\u30fc\u8fd4\u3057\u306f\u624b\u52d5\u3067\u3059\u3002\u300c\u30d5\u30a9\u30ed\u30fc\u3057\u3066\u300d\u3068\u30ea\u30d7\u304f\u3060\u3055\u308c\u3070\u30d5\u30a9\u30ed\u30d0\u3057\u307e\u3059\u3002\u304a\u5225\u308c\u306f\u30d6\u30ed\u30c3\u30af\u3067\uff01", "translator_type": "none", "protected": false, "verified": false, "followers_count": 138, "friends_count": 27, "listed_count": 2, "favourites_count": 0, "statuses_count": 47810, "created_at": "Sat Nov 17 04:07:26 +0000 2012", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": null, "contributors_enabled": false, "is_translator": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/2859121435/4e12315bba26afcfed32026643d12255_normal.jpeg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/2859121435/4e12315bba26afcfed32026643d12255_normal.jpeg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/952892462/1353125498", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "quote_count": 0, "reply_count": 0, "retweet_count": 0, "favorite_count": 0, "entities": {"hashtags": [], "urls": [], "user_mentions": [], "symbols": []}, "favorited": false, "retweeted": false, "filter_level": "low", "lang": "ja", "timestamp_ms": "1572677523661"}
# {"created_at": "Sat Nov 02 06:52:03 +0000 2019", "id": 1190521938663198720, "id_str": "1190521938663198720", "text": "\u30b2\u30fc\u30e0\u304b\u3068\u601d\u3063\u305f\u3089\u5b9f\u969b\u306b\u4e57\u308b\u306e\u306d!?", "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 1158960103891935233, "id_str": "1158960103891935233", "name": "\u306f\u308b", "screen_name": "hr_htnk", "location": "\u4e00\u751f\u8ab0\u304b\u306e\u304a\u3082\u3061\u3083\u3002", "url": null, "description": "\u5b66\u751f\uffe4\u7560\u4e2d\u7950\u3055\u3093\uffe4\u2691\ufe0e\u2690\ufe0e", "translator_type": "none", "protected": false, "verified": false, "followers_count": 15, "friends_count": 63, "listed_count": 0, "favourites_count": 559, "statuses_count": 209, "created_at": "Wed Aug 07 04:36:35 +0000 2019", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": null, "contributors_enabled": false, "is_translator": false, "profile_background_color": "F5F8FA", "profile_background_image_url": "", "profile_background_image_url_https": "", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/1160543030429925376/b6RtBYN9_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/1160543030429925376/b6RtBYN9_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/1158960103891935233/1570457723", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "quote_count": 0, "reply_count": 0, "retweet_count": 0, "favorite_count": 0, "entities": {"hashtags": [], "urls": [], "user_mentions": [], "symbols": []}, "favorited": false, "retweeted": false, "filter_level": "low", "lang": "ja", "timestamp_ms": "1572677523662"}
# {"created_at": "Sat Nov 02 06:52:03 +0000 2019", "id": 1190521938654842882, "id_str": "1190521938654842882", "text": "\u5bb6\u755c\u4eba\u30e4\u30d7\u30fc\u3092\u8aad\u3093\u3067\u307f\u3088\u3046\u3002", "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 789070729207623680, "id_str": "789070729207623680", "name": "\u304b\u3055\u306d", "screen_name": "kasaneruomoi", "location": null, "url": null, "description": "\u30d5\u30a7\u30df\u30cb\u30b9\u30c8\u3053\u308f\u3044\u3002", "translator_type": "none", "protected": false, "verified": false, "followers_count": 18, "friends_count": 73, "listed_count": 0, "favourites_count": 95, "statuses_count": 202, "created_at": "Thu Oct 20 11:48:16 +0000 2016", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": null, "contributors_enabled": false, "is_translator": false, "profile_background_color": "000000", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_link_color": "19CF86", "profile_sidebar_border_color": "000000", "profile_sidebar_fill_color": "000000", "profile_text_color": "000000", "profile_use_background_image": false, "profile_image_url": "http://pbs.twimg.com/profile_images/1117980815348998149/Fy0ptkuy_normal.png", "profile_image_url_https": "https://pbs.twimg.com/profile_images/1117980815348998149/Fy0ptkuy_normal.png", "default_profile": false, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "quote_count": 0, "reply_count": 0, "retweet_count": 0, "favorite_count": 0, "entities": {"hashtags": [], "urls": [], "user_mentions": [], "symbols": []}, "favorited": false, "retweeted": false, "filter_level": "low", "lang": "ja", "timestamp_ms": "1572677523660"}
# {"created_at": "Sat Nov 02 06:52:03 +0000 2019", "id": 1190521938663182337, "id_str": "1190521938663182337", "text": "RT @gokurezi: \u3069\u3046\u3057\u3066\u30ec\u30aa\u30d1\u30eb\u30c9\u30f3\u304c\u30c8\u30ec\u30f3\u30c9\u5165\u308a\u3057\u3066\u308b\u3093\u3067\u3059\u304b https://t.co/11MHUeyhfr", "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 18309143, "id_str": "18309143", "name": "GAN", "screen_name": "gangando", "location": "\u30bb\u30a4\u30d0\u30fc\u30c8\u30ed\u30f3\u661f", "url": "http://gangando.blog87.fc2.com/", "description": "\u30a8\u30cd\u30eb\u30b4\u30f3\u3092\u98df\u3079\u308b\u3068\u3044\u3044\u8003\u3048\u304c\u6d6e\u304b\u3073\u307e\u3059\u3002\nhttps://www.pixiv.net/member.php?id=1015629", "translator_type": "none", "protected": false, "verified": false, "followers_count": 544, "friends_count": 325, "listed_count": 43, "favourites_count": 595, "statuses_count": 30834, "created_at": "Mon Dec 22 15:48:59 +0000 2008", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": null, "contributors_enabled": false, "is_translator": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/1187621888010252289/hGyy0E8W_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/1187621888010252289/hGyy0E8W_normal.jpg", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "retweeted_status": {"created_at": "Sat Nov 02 05:05:00 +0000 2019", "id": 1190494998677975046, "id_str": "1190494998677975046", "text": "\u3069\u3046\u3057\u3066\u30ec\u30aa\u30d1\u30eb\u30c9\u30f3\u304c\u30c8\u30ec\u30f3\u30c9\u5165\u308a\u3057\u3066\u308b\u3093\u3067\u3059\u304b https://t.co/11MHUeyhfr", "display_text_range": [0, 24], "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 740450415909732352, "id_str": "740450415909732352", "name": "gokure \u6687\u3002", "screen_name": "gokurezi", "location": "\u65e5\u672c", "url": "http://gokure.blog.fc2.com/", "description": "\u30cd\u30c3\u30c8\u3067\u30de\u30f3\u30ac\u63cf\u3044\u305f\u308a\u540c\u4eba\u8a8c\u4f5c\u3063\u305f\u308a\u3002\u3000\u81ea\u5bb6\u901a\u8ca9\u306f\u6b21\u56de\u672a\u5b9a\u3002https://gokureido.thebase.in   \u30bb\u30f3\u30b7\u30c6\u30a3\u30d6\u306a\u5185\u5bb9\u3092\u542b\u3080TWEET\u3082\u3042\u308a\u307e\u3059\u306e\u3067\uff11\uff18\u6b73\u672a\u6e80\u306f\u30d6\u30ed\u30c3\u30af\u3057\u307e\u3059\u3002 http://www.pixiv.net/member.php?id=7424776", "translator_type": "none", "protected": false, "verified": false, "followers_count": 17220, "friends_count": 955, "listed_count": 263, "favourites_count": 82303, "statuses_count": 13355, "created_at": "Wed Jun 08 07:48:30 +0000 2016", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": null, "contributors_enabled": false, "is_translator": false, "profile_background_color": "F5F8FA", "profile_background_image_url": "", "profile_background_image_url_https": "", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_c ...
# {"created_at": "Sat Nov 02 06:52:03 +0000 2019", "id": 1190521938663231488, "id_str": "1190521938663231488", "text": "\u5148\u751f\u306e\u30e2\u30ce\u30de\u30cd\u3084\u53e3\u7656\u304c\u3084\u305f\u3089\u4e0a\u624b\u3044\u4eba\u304c\u3044\u308b", "source": "<a href=\"http://twittbot.net/\" rel=\"nofollow\">twittbot.net</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 2983877173, "id_str": "2983877173", "name": "S\u5973\u5b50\u5927\u9644\u5c5e\u4e2d\u9ad8\u90e8bot", "screen_name": "SWUchuukoubu", "location": null, "url": null, "description": "\u3042\u308b\u3042\u308b\u3084\u7528\u8a9e\u306a\u3069\u3064\u3076\u3084\u304fbot\u3067\u3059\u3002\u30cd\u30bf\u3082\u52df\u96c6\u3057\u3066\u3044\u307e\u3059\u3002", "translator_type": "none", "protected": false, "verified": false, "followers_count": 48, "friends_count": 39, "listed_count": 0, "favourites_count": 0, "statuses_count": 13487, "created_at": "Thu Jan 15 08:23:31 +0000 2015", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": null, "contributors_enabled": false, "is_translator": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/555893448339775489/m0qlPgCw_normal.jpeg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/555893448339775489/m0qlPgCw_normal.jpeg", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "quote_count": 0, "reply_count": 0, "retweet_count": 0, "favorite_count": 0, "entities": {"hashtags": [], "urls": [], "user_mentions": [], "symbols": []}, "favorited": false, "retweeted": false, "filter_level": "low", "lang": "ja", "timestamp_ms": "1572677523662"}
# {"created_at": "Sat Nov 02 06:52:03 +0000 2019", "id": 1190521938667438080, "id_str": "1190521938667438080", "text": "RT @HIPsToeY_G7: \u0e2a\u0e23\u0e38\u0e1b\u0e27\u0e31\u0e19\u0e19\u0e35\u0e49\u0e2d\u0e34\u0e19\u0e01\u0e01\u0e47\u0e04\u0e37\u0e2d\u0e40\u0e1b\u0e25\u0e35\u0e48\u0e22\u0e19\u0e41\u0e1c\u0e19\u0e44\u0e1b\u0e41\u0e14\u0e01\u0e1a\u0e38\u0e1f\u0e40\u0e1f\u0e48\u0e15\u0e4c\u0e01\u0e31\u0e19\u0e41\u0e1a\u0e1a\u0e01\u0e30\u0e17\u0e31\u0e19\u0e2b\u0e31\u0e19\u0e2a\u0e38\u0e14 \u0e41\u0e14\u0e01\u0e44\u0e1b\u0e42\u0e1a\u0e01\u0e1a\u0e07\u0e44\u0e1b \u0e1e\u0e23\u0e49\u0e2d\u0e21\u0e01\u0e31\u0e1a\u0e01\u0e49\u0e21\u0e2b\u0e19\u0e49\u0e32\u0e14\u0e48\u0e32\u0e2d\u0e34\u0e04\u0e48\u0e32\u0e22\u0e40\u0e27\u0e23\u0e43\u0e19\u0e17\u0e27\u0e34\u0e15\u0e40\u0e15\u0e2d\u0e23\u0e4c\u0e43\u0e2b\u0e49\u0e2a\u0e32\u0e2a\u0e21\u0e01\u0e31\u0e1a\u0e04\u2026", "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 1958018936, "id_str": "1958018936", "name": "\u0e41\u0e17\u0e22\u0e2d\u0e07\u0e40\u0e1b\u0e47\u0e19\u0e40\u0e1e\u0e37\u0e48\u0e2d\u0e19\u0e41\u0e08\u0e1a\u0e2d\u0e21", "screen_name": "teyyongG", "location": null, "url": null, "description": "080919 \u2661", "translator_type": "none", "protected": false, "verified": false, "followers_count": 77, "friends_count": 64, "listed_count": 1, "favourites_count": 1192, "statuses_count": 57897, "created_at": "Sun Oct 13 04:58:14 +0000 2013", "utc_offset": null, "time_zone": null, "geo_enabled": true, "lang": null, "contributors_enabled": false, "is_translator": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": true, "profile_link_color": "E66879", "profile_sidebar_border_color": "FFFFFF", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/1187255484677382144/l2FakWKo_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/1187255484677382144/l2FakWKo_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/1958018936/1569744636", "default_profile": false, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "retweeted_status": {"created_at": "Sat Nov 02 04:20:20 +0000 2019", "id": 1190483759151271936, "id_str": "1190483759151271936", "text": "\u0e2a\u0e23\u0e38\u0e1b\u0e27\u0e31\u0e19\u0e19\u0e35\u0e49\u0e2d\u0e34\u0e19\u0e01\u0e01\u0e47\u0e04\u0e37\u0e2d\u0e40\u0e1b\u0e25\u0e35\u0e48\u0e22\u0e19\u0e41\u0e1c\u0e19\u0e44\u0e1b\u0e41\u0e14\u0e01\u0e1a\u0e38\u0e1f\u0e40\u0e1f\u0e48\u0e15\u0e4c\u0e01\u0e31\u0e19\u0e41\u0e1a\u0e1a\u0e01\u0e30\u0e17\u0e31\u0e19\u0e2b\u0e31\u0e19\u0e2a\u0e38\u0e14 \u0e41\u0e14\u0e01\u0e44\u0e1b\u0e42\u0e1a\u0e01\u0e1a\u0e07\u0e44\u0e1b \u0e1e\u0e23\u0e49\u0e2d\u0e21\u0e01\u0e31\u0e1a\u0e01\u0e49\u0e21\u0e2b\u0e19\u0e49\u0e32\u0e14\u0e48\u0e32\u0e2d\u0e34\u0e04\u0e48\u0e32\u0e22\u0e40\u0e27\u0e23\u0e43\u0e19\u0e17\u0e27\u0e34\u0e15\u0e40\u0e15\u0e2d\u0e23\u0e4c\u0e43\u0e2b\u0e49\u0e2a\u2026 https://t.co/dIx2QEs92n", "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "truncated": true, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 218680417, "id_str": "218680417", "name": "*\u0e04\u0e39\u0e21\u0e21\u0e35\u0e4a* \ud802\udf39\u200e \u2729 \ud802\udf39\u0e41\u0e21\u0e48\u0e19\u0e49\u ...
# {"created_at": "Sat Nov 02 06:52:03 +0000 2019", "id": 1190521938650652672, "id_str": "1190521938650652672", "text": "RT @notIena: girls will never admit to liking you, we just start talking to you every day", "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 3019075962, "id_str": "3019075962", "name": "nani\ud83d\udc22", "screen_name": "nanileii", "location": "its litty", "url": null, "description": "The way you treat me is your path, the way I react is mine\ud83d\udc9b\ud83c\udf39", "translator_type": "none", "protected": false, "verified": false, "followers_count": 310, "friends_count": 360, "listed_count": 4, "favourites_count": 83128, "statuses_count": 35151, "created_at": "Sat Feb 14 04:00:31 +0000 2015", "utc_offset": null, "time_zone": null, "geo_enabled": true, "lang": null, "contributors_enabled": false, "is_translator": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/1178066403288436737/1DrKE0NR_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/1178066403288436737/1DrKE0NR_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/3019075962/1497945587", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "retweeted_status": {"created_at": "Wed Oct 30 00:25:38 +0000 2019", "id": 1189337530547744768, "id_str": "1189337530547744768", "text": "girls will never admit to liking you, we just start talking to you every day", "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 1185575039275556866, "id_str": "1185575039275556866", "name": "lena", "screen_name": "notIena", "location": "turn on notifications \ud83d\udc98", "url": "https://twitter.com/notIena", "description": "follow me to hear me complain about being single", "translator_type": "none", "protected": false, "verified": false, "followers_count": 3292, "friends_count": 382, "listed_count": 4, "favourites_count": 413, "statuses_count": 18, "created_at": "Sat Oct 19 15:14:59 +0000 2019", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": null, "contributors_enabled": false, "is_translator": false, "profile_background_color": "000000", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_link_color": "F58EA8", "profile_sidebar_border_color": "000000", "profile_sidebar_fill_color": "000000", "profile_text_color": "000000", "profile_use_background_image": false, "profile_image_url": "http://pbs.twimg.com/profile_images/1189006248714350592/SB02WTQz_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/1189006248714350592/SB02WTQz_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/1185575039275556866/1572316156", "default_profile": false, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null,  ...
# {"created_at": "Sat Nov 02 06:52:03 +0000 2019", "id": 1190521938646458368, "id_str": "1190521938646458368", "text": "\u307e\u3041\u307e\u3041\u524d\u3067\u898b\u308c\u307e\u3057\u305f\uff01\ud83d\ude0c", "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "truncated": false, "in_reply_to_status_id": 1190507949598240768, "in_reply_to_status_id_str": "1190507949598240768", "in_reply_to_user_id": 910848447149772801, "in_reply_to_user_id_str": "910848447149772801", "in_reply_to_screen_name": "harishin000", "user": {"id": 910848447149772801, "id_str": "910848447149772801", "name": "\u9ea6\u308f\u3089\u306e\u30cf\u30ea\u30a3@\u304f\u308b\u3059\u305f", "screen_name": "harishin000", "location": "\u795e\u5948\u5ddd\u770c\u6a2a\u6d5c\u5e02", "url": null, "description": "\u6765\u6816\u308a\u3093\u3092\u3053\u3088\u306a\u304f\u611b\u3059\u308b\u30e2\u30f3\u30ad\u30fc\uff65D\uff65\u30eb\u30d5\u30a3\u304c\u5927\u597d\u304d\u306aIT\u30b5\u30fc\u30d3\u30b9\u4e8b\u696d\u306e\u30b3\u30f3\u30b5\u30eb\u30bf\u30f3\u30c8\u3002\u4f11\u65e5\u306f\u30aa\u30bf\u6d3b\u3002\u4e3b\u73fe\u5834:26\u6642\u306e\u30de\u30b9\u30ab\u30ec\u30a4\u30c9 @nijimasu_rinrin https://26masquerade.com @nijimasu_staff", "translator_type": "none", "protected": false, "verified": false, "followers_count": 320, "friends_count": 317, "listed_count": 9, "favourites_count": 14877, "statuses_count": 6048, "created_at": "Thu Sep 21 12:49:27 +0000 2017", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": null, "contributors_enabled": false, "is_translator": false, "profile_background_color": "F5F8FA", "profile_background_image_url": "", "profile_background_image_url_https": "", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/1183034900099657730/Kd4Sf2q0_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/1183034900099657730/Kd4Sf2q0_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/910848447149772801/1570894668", "default_profile": true, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "quote_count": 0, "reply_count": 0, "retweet_count": 0, "favorite_count": 0, "entities": {"hashtags": [], "urls": [], "user_mentions": [], "symbols": []}, "favorited": false, "retweeted": false, "filter_level": "low", "lang": "ja", "timestamp_ms": "1572677523658"}

# %% [markdown]
# ### Tracking a specific keyword in stream

# %%
iterator = twitter_stream.statuses.filter(track="Mumbai Monsoon", language="en")
tweet_count = 3
for tweet in iterator:
    tweet_count -= 1
    
    print(json.dumps(tweet) )
       
    if tweet_count <= 0:
        break
# Out:
# {"created_at": "Sat Nov 02 07:01:01 +0000 2019", "id": 1190524196469690368, "id_str": "1190524196469690368", "text": "RT @sahil11p: @KiranManral it did rain in November 2009 due to cyclone phyan and latest in Dec 2017 due to cyclone Ockhi....Mumbai does get\u2026", "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "truncated": false, "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 1453180627, "id_str": "1453180627", "name": "\u0927\u094d\u0930\u0941\u0935 \u092d\u0940\u092e\u0930\u093e\u091c\u0915\u093e \ud83c\uddee\ud83c\uddf3", "screen_name": "dhruvbhim", "location": null, "url": null, "description": "https://transformingindia.mygov.in/performance-dashboard/\nviews are strictly personal.", "translator_type": "none", "protected": false, "verified": false, "followers_count": 4515, "friends_count": 108, "listed_count": 672, "favourites_count": 1015931, "statuses_count": 845022, "created_at": "Fri May 24 03:57:07 +0000 2013", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": null, "contributors_enabled": false, "is_translator": false, "profile_background_color": "000000", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme17/bg.gif", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme17/bg.gif", "profile_background_tile": false, "profile_link_color": "89C9FA", "profile_sidebar_border_color": "000000", "profile_sidebar_fill_color": "000000", "profile_text_color": "000000", "profile_use_background_image": false, "profile_image_url": "http://pbs.twimg.com/profile_images/1144591681435496449/hKpVmh4a_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/1144591681435496449/hKpVmh4a_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/1453180627/1502609211", "default_profile": false, "default_profile_image": false, "following": null, "follow_request_sent": null, "notifications": null}, "geo": null, "coordinates": null, "place": null, "contributors": null, "retweeted_status": {"created_at": "Fri Nov 01 12:41:37 +0000 2019", "id": 1190247520909185024, "id_str": "1190247520909185024", "text": "@KiranManral it did rain in November 2009 due to cyclone phyan and latest in Dec 2017 due to cyclone Ockhi....Mumba\u2026 https://t.co/pcwo0B4vNC", "display_text_range": [13, 140], "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>", "truncated": true, "in_reply_to_status_id": 1190230815466127361, "in_reply_to_status_id_str": "1190230815466127361", "in_reply_to_user_id": 18210579, "in_reply_to_user_id_str": "18210579", "in_reply_to_screen_name": "KiranManral", "user": {"id": 102083006, "id_str": "102083006", "name": "Sahil Pednekar", "screen_name": "sahil11p", "location": "Mumbai ", "url": null, "description": "Ignorance brings chaos, not knowledge.\nHighly optimistic, hate negativity.", "translator_type": "none", "protected": false, "verified": false, "followers_count": 5670, "friends_count": 6, "listed_count": 24, "favourites_count": 615, "statuses_count": 7950, "created_at": "Tue Jan 05 15:05:31 +0000 2010", "utc_offset": null, "time_zone": null, "geo_enabled": false, "lang": null, "contributors_enabled": false, "is_translator": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/1038792932038459393/w9D8a2bX_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/ ...
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# <ipython-input-55-b65a35901bc8> in <module>()
#       1 iterator = twitter_stream.statuses.filter(track="Mumbai Monsoon", language="en")
#       2 tweet_count = 3
# ----> 3 for tweet in iterator:
#       4     tweet_count -= 1
#       5
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\twitter\stream.py in __iter__(self)
#     175             # Decode all the things:
#     176             try:
# --> 177                 data = sock_reader.read()
#     178             except SSLError:
#     179                 yield Hangup
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\twitter\stream.py in read(self)
#     133             ready_to_read = select.select([self.sock], [], [], self.sock_timeout)[0]
#     134             if ready_to_read:
# --> 135                 return self.sock.read()
#     136         except SSLError as e:
#     137             # Code 2 is error from a non-blocking read of an empty buffer.
#
# ~\AppData\Local\Continuum\anaconda3\lib\ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~\AppData\Local\Continuum\anaconda3\lib\ssl.py in read(self, len, buffer)
#     631             v = self._sslobj.read(len, buffer)
#     632         else:
# --> 633             v = self._sslobj.read(len)
#     634         return v
#     635
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host

# %% [markdown]
# ### trends API

# %%
world_trends = twitter.trends.available(_woeid=1)
world_trends[1:3]
# Out:
# [{'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Winnipeg',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2972',
#   'woeid': 2972},
#  {'country': 'Canada',
#   'countryCode': 'CA',
#   'name': 'Ottawa',
#   'parentid': 23424775,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3369',
#   'woeid': 3369}]

# %%
hyd_trend=twitter.trends.place(_id = 2295414)

# %%
print(json.dumps(hyd_trend, indent=4))
# Out:
# [
#     {
#         "trends": [
#             {
#                 "name": "#HappyBirthdaySRK",
#                 "url": "http://twitter.com/search?q=%23HappyBirthdaySRK",
#                 "promoted_content": null,
#                 "query": "%23HappyBirthdaySRK",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#\u091b\u0920_\u092e\u0939\u093e\u092a\u0930\u094d\u0935",
#                 "url": "http://twitter.com/search?q=%23%E0%A4%9B%E0%A4%A0_%E0%A4%AE%E0%A4%B9%E0%A4%BE%E0%A4%AA%E0%A4%B0%E0%A5%8D%E0%A4%B5",
#                 "promoted_content": null,
#                 "query": "%23%E0%A4%9B%E0%A4%A0_%E0%A4%AE%E0%A4%B9%E0%A4%BE%E0%A4%AA%E0%A4%B0%E0%A5%8D%E0%A4%B5",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#DelhiAirEmergency",
#                 "url": "http://twitter.com/search?q=%23DelhiAirEmergency",
#                 "promoted_content": null,
#                 "query": "%23DelhiAirEmergency",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#\u0bb5\u0bbe\u0bb4\u0bcd\u0ba8\u0bbe\u0bb3\u0bcd\u0b9a\u0bbe\u0ba4\u0ba9\u0bc8\u0baf\u0bbe\u0bb3\u0bb0\u0bcd\u0bb0\u0b9c\u0bbf\u0ba9\u0bbf",
#                 "url": "http://twitter.com/search?q=%23%E0%AE%B5%E0%AE%BE%E0%AE%B4%E0%AF%8D%E0%AE%A8%E0%AE%BE%E0%AE%B3%E0%AF%8D%E0%AE%9A%E0%AE%BE%E0%AE%A4%E0%AE%A9%E0%AF%88%E0%AE%AF%E0%AE%BE%E0%AE%B3%E0%AE%B0%E0%AF%8D%E0%AE%B0%E0%AE%9C%E0%AE%BF%E0%AE%A9%E0%AE%BF",
#                 "promoted_content": null,
#                 "query": "%23%E0%AE%B5%E0%AE%BE%E0%AE%B4%E0%AF%8D%E0%AE%A8%E0%AE%BE%E0%AE%B3%E0%AF%8D%E0%AE%9A%E0%AE%BE%E0%AE%A4%E0%AE%A9%E0%AF%88%E0%AE%AF%E0%AE%BE%E0%AE%B3%E0%AE%B0%E0%AF%8D%E0%AE%B0%E0%AE%9C%E0%AE%BF%E0%AE%A9%E0%AE%BF",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#HBDWorldsBiggestMovieStar",
#                 "url": "http://twitter.com/search?q=%23HBDWorldsBiggestMovieStar",
#                 "promoted_content": null,
#                 "query": "%23HBDWorldsBiggestMovieStar",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "\u0932\u094b\u0915 \u0906\u0938\u094d\u0925\u093e",
#                 "url": "http://twitter.com/search?q=%22%E0%A4%B2%E0%A5%8B%E0%A4%95+%E0%A4%86%E0%A4%B8%E0%A5%8D%E0%A4%A5%E0%A4%BE%22",
#                 "promoted_content": null,
#                 "query": "%22%E0%A4%B2%E0%A5%8B%E0%A4%95+%E0%A4%86%E0%A4%B8%E0%A5%8D%E0%A4%A5%E0%A4%BE%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Meghalaya",
#                 "url": "http://twitter.com/search?q=Meghalaya",
#                 "promoted_content": null,
#                 "query": "Meghalaya",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Chak De India",
#                 "url": "http://twitter.com/search?q=%22Chak+De+India%22",
#                 "promoted_content": null,
#                 "query": "%22Chak+De+India%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Kabhi Haan Kabhi Naa",
#                 "url": "http://twitter.com/search?q=%22Kabhi+Haan+Kabhi+Naa%22",
#                 "promoted_content": null,
#                 "query": "%22Kabhi+Haan+Kabhi+Naa%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Swades",
#                 "url": "http://twitter.com/search?q=Swades",
#                 "promoted_content": null,
#                 "query": "Swades",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Kuch Kuch Hota Hai",
#                 "url": "http://twitter.com/search?q=%22Kuch+Kuch+Hota+Hai%22",
#                 "promoted_content": null,
#                 "query": "%22Kuch+Kuch+Hota+Hai%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "tatkal",
#                 "url": "http://twitter.com/search?q=tatkal",
#                 "promoted_content": null,
#                 "query": "tatkal",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#SaturdayMotivation",
#                 "url": "http://twitter.com/search?q=%23SaturdayMotivation",
#                 "promoted_content": null,
#                 "query": "%23SaturdayMotivation",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#IFFI2019",
#                 "url": "http://twitter.com/search?q=%23IFFI2019",
#                 "promoted_content": null,
#                 "query": "%23IFFI2019",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#SackManishMaheshwari",
#                 "url": "http://twitter.com/search?q=%23SackManishMaheshwari",
#                 "promoted_content": null,
#                 "query": "%23SackManishMaheshwari",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#SRKians",
#                 "url": "http://twitter.com/search?q=%23SRKians",
#                 "promoted_content": null,
#                 "query": "%23SRKians",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#WhatsAppSpygate",
#                 "url": "http://twitter.com/search?q=%23WhatsAppSpygate",
#                 "promoted_content": null,
#                 "query": "%23WhatsAppSpygate",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#\ubaac\ubca0\ubca0_\uc6d0\ud638_\uc751\uc6d0\ud574",
#                 "url": "http://twitter.com/search?q=%23%EB%AA%AC%EB%B2%A0%EB%B2%A0_%EC%9B%90%ED%98%B8_%EC%9D%91%EC%9B%90%ED%95%B4",
#                 "promoted_content": null,
#                 "query": "%23%EB%AA%AC%EB%B2%A0%EB%B2%A0_%EC%9B%90%ED%98%B8_%EC%9D%91%EC%9B%90%ED%95%B4",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#AzadiMarchForDemocracy",
#                 "url": "http://twitter.com/search?q=%23AzadiMarchForDemocracy",
#                 "promoted_content": null,
#                 "query": "%23AzadiMarchForDemocracy",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#droidconIN",
#                 "url": "http://twitter.com/search?q=%23droidconIN",
#                 "promoted_content": null,
#                 "query": "%23droidconIN",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#PriyaAnand",
#                 "url": "http://twitter.com/search?q=%23PriyaAnand",
#                 "promoted_content": null,
#                 "query": "%23PriyaAnand",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#AV30Title",
#                 "url": "http://twitter.com/search?q=%23AV30Title",
#                 "promoted_content": null,
#                 "query": "%23AV30Title",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#6DaysToGoforMMA",
#                 "url": "http://twitter.com/search?q=%236DaysToGoforMMA",
#                 "promoted_content": null,
#                 "query": "%236DaysToGoforMMA",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#Thailand",
#                 "url": "http://twitter.com/search?q=%23Thailand",
#                 "promoted_content": null,
#                 "query": "%23Thailand",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#SangaThamizhan",
#                 "url": "http://twitter.com/search?q=%23SangaThamizhan",
#                 "promoted_content": null,
#                 "query": "%23SangaThamizhan",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#LakeShow",
#                 "url": "http://twitter.com/search?q=%23LakeShow",
#                 "promoted_content": null,
#                 "query": "%23LakeShow",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#SangaTamizhanFromNov15th",
#                 "url": "http://twitter.com/search?q=%23SangaTamizhanFromNov15th",
#                 "promoted_content": null,
#                 "query": "%23SangaTamizhanFromNov15th",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#AdithyaVarmaThisNovember",
#                 "url": "http://twitter.com/search?q=%23AdithyaVarmaThisNovember",
#                 "promoted_content": null,
#                 "query": "%23AdithyaVarmaThisNovember",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#ChaloVisakhapatnam",
#                 "url": "http://twitter.com/search?q=%23ChaloVisakhapatnam",
#                 "promoted_content": null,
#                 "query": "%23ChaloVisakhapatnam",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#SmackDown",
#                 "url": "http://twitter.com/search?q=%23SmackDown",
#                 "promoted_content": null,
#                 "query": "%23SmackDown",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#VaijanathPatil",
#                 "url": "http://twitter.com/search?q=%23VaijanathPatil",
#                 "promoted_content": null,
#                 "query": "%23VaijanathPatil",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#askprsundar",
#                 "url": "http://twitter.com/search?q=%23askprsundar",
#                 "promoted_content": null,
#                 "query": "%23askprsundar",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#SundarArumugam",
#                 "url": "http://twitter.com/search?q=%23SundarArumugam",
#                 "promoted_content": null,
#                 "query": "%23SundarArumugam",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#Thumka",
#                 "url": "http://twitter.com/search?q=%23Thumka",
#                 "promoted_content": null,
#                 "query": "%23Thumka",
#                 "tweet_volume": null
#             }
#         ],
#         "as_of": "2019-11-02T07:13:06Z",
#         "created_at": "2019-11-02T07:07:31Z",
#         "locations": [
#             {
#                 "name": "Hyderabad",
#                 "woeid": 2295414
#             }
#         ]
#     }
# ]

# %% [markdown]
# ### User API

# %%
# Get a list of followers of a particular user
twitter.followers.ids(screen_name="mayankveedwal")
# Out:
# {'ids': [188599111,
#   964531329911152640,
#   953148819943731200,
#   4537242024,
#   830401508109905920,
#   2915722141,
#   805800405036695552],
#  'next_cursor': 0,
#  'next_cursor_str': '0',
#  'previous_cursor': 0,
#  'previous_cursor_str': '0',
#  'total_count': None}

# %%
twitter.statuses.user_timeline(screen_name="mayankveedwal")
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jan 10 17:57:30 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/NuRC2W87FF',
#      'expanded_url': 'https://twitter.com/mayankveedwal/status/818879454185295872/photo/1',
#      'features': {'large': {'faces': []},
#       'medium': {'faces': []},
#       'orig': {'faces': []},
#       'small': {'faces': []}},
#      'id': 818879448640462848,
#      'id_str': '818879448640462848',
#      'indices': [16, 39],
#      'media_url': 'http://pbs.twimg.com/media/C10-hRoVIAA9FYp.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C10-hRoVIAA9FYp.jpg',
#      'sizes': {'large': {'h': 497, 'resize': 'fit', 'w': 623},
#       'medium': {'h': 497, 'resize': 'fit', 'w': 623},
#       'small': {'h': 497, 'resize': 'fit', 'w': 623},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/NuRC2W87FF'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 405427035,
#      'id_str': '405427035',
#      'indices': [0, 15],
#      'name': 'Arvind Kejriwal',
#      'screen_name': 'ArvindKejriwal'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/NuRC2W87FF',
#      'expanded_url': 'https://twitter.com/mayankveedwal/status/818879454185295872/photo/1',
#      'features': {'large': {'faces': []},
#       'medium': {'faces': []},
#       'orig': {'faces': []},
#       'small': {'faces': []}},
#      'id': 818879448640462848,
#      'id_str': '818879448640462848',
#      'indices': [16, 39],
#      'media_url': 'http://pbs.twimg.com/media/C10-hRoVIAA9FYp.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C10-hRoVIAA9FYp.jpg',
#      'sizes': {'large': {'h': 497, 'resize': 'fit', 'w': 623},
#       'medium': {'h': 497, 'resize': 'fit', 'w': 623},
#       'small': {'h': 497, 'resize': 'fit', 'w': 623},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/NuRC2W87FF'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 818879454185295872,
#   'id_str': '818879454185295872',
#   'in_reply_to_screen_name': 'ArvindKejriwal',
#   'in_reply_to_status_id': 818762390279884803,
#   'in_reply_to_status_id_str': '818762390279884803',
#   'in_reply_to_user_id': 405427035,
#   'in_reply_to_user_id_str': '405427035',
#   'is_quote_status': False,
#   'lang': 'und',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@ArvindKejriwal https://t.co/NuRC2W87FF',
#   'truncated': False,
#   'user': {'can_media_tag': True,
#    'contributors_enabled': False,
#    'created_at': 'Mon Dec 05 15:47:15 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Sports Indian Athletes Cricketers and Commentators Leagues and Teams Sports News, TV and Scores Hindi Music Music',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 16,
#    'follow_request_sent': False,
#    'followed_by': False,
#    'followers_count': 7,
#    'following': False,
#    'friends_count': 106,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 805800713561391109,
#    'id_str': '805800713561391109',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'मुंबई, भारत',
#    'name': 'Mayank Sharma',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805800713561391109/1480953771',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'mayankveedwal',
#    'statuses_count': 15,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jan 10 13:57:47 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/17aUvC3dxb',
#      'expanded_url': 'https://twitter.com/mayankveedwal/status/818819128899305472/photo/1',
#      'features': {'large': {'faces': [{'h': 69, 'w': 69, 'x': 92, 'y': 23},
#         {'h': 99, 'w': 99, 'x': 95, 'y': 145},
#         {'h': 93, 'w': 93, 'x': 377, 'y': 48}]},
#       'medium': {'faces': [{'h': 69, 'w': 69, 'x': 92, 'y': 23},
#         {'h': 99, 'w': 99, 'x': 95, 'y': 145},
#         {'h': 93, 'w': 93, 'x': 377, 'y': 48}]},
#       'orig': {'faces': [{'h': 69, 'w': 69, 'x': 92, 'y': 23},
#         {'h': 99, 'w': 99, 'x': 95, 'y': 145},
#         {'h': 93, 'w': 93, 'x': 377, 'y': 48}]},
#       'small': {'faces': [{'h': 69, 'w': 69, 'x': 92, 'y': 23},
#         {'h': 99, 'w': 99, 'x': 95, 'y': 145},
#         {'h': 93, 'w': 93, 'x': 377, 'y': 48}]}},
#      'id': 818819123899727874,
#      'id_str': '818819123899727874',
#      'indices': [64, 87],
#      'media_url': 'http://pbs.twimg.com/media/C10Hp6dXAAIQ4Nu.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C10Hp6dXAAIQ4Nu.jpg',
#      'sizes': {'large': {'h': 422, 'resize': 'fit', 'w': 511},
#       'medium': {'h': 422, 'resize': 'fit', 'w': 511},
#       'small': {'h': 422, 'resize': 'fit', 'w': 511},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/17aUvC3dxb'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 405427035,
#      'id_str': '405427035',
#      'indices': [0, 15],
#      'name': 'Arvind Kejriwal',
#      'screen_name': 'ArvindKejriwal'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/17aUvC3dxb',
#      'expanded_url': 'https://twitter.com/mayankveedwal/status/818819128899305472/photo/1',
#      'features': {'large': {'faces': [{'h': 69, 'w': 69, 'x': 92, 'y': 23},
#         {'h': 99, 'w': 99, 'x': 95, 'y': 145},
#         {'h': 93, 'w': 93, 'x': 377, 'y': 48}]},
#       'medium': {'faces': [{'h': 69, 'w': 69, 'x': 92, 'y': 23},
#         {'h': 99, 'w': 99, 'x': 95, 'y': 145},
#         {'h': 93, 'w': 93, 'x': 377, 'y': 48}]},
#       'orig': {'faces': [{'h': 69, 'w': 69, 'x': 92, 'y': 23},
#         {'h': 99, 'w': 99, 'x': 95, 'y': 145},
#         {'h': 93, 'w': 93, 'x': 377, 'y': 48}]},
#       'small': {'faces': [{'h': 69, 'w': 69, 'x': 92, 'y': 23},
#         {'h': 99, 'w': 99, 'x': 95, 'y': 145},
#         {'h': 93, 'w': 93, 'x': 377, 'y': 48}]}},
#      'id': 818819123899727874,
#      'id_str': '818819123899727874',
#      'indices': [64, 87],
#      'media_url': 'http://pbs.twimg.com/media/C10Hp6dXAAIQ4Nu.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C10Hp6dXAAIQ4Nu.jpg',
#      'sizes': {'large': {'h': 422, 'resize': 'fit', 'w': 511},
#       'medium': {'h': 422, 'resize': 'fit', 'w': 511},
#       'small': {'h': 422, 'resize': 'fit', 'w': 511},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/17aUvC3dxb'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 818819128899305472,
#   'id_str': '818819128899305472',
#   'in_reply_to_screen_name': 'ArvindKejriwal',
#   'in_reply_to_status_id': 818677534124408832,
#   'in_reply_to_status_id_str': '818677534124408832',
#   'in_reply_to_user_id': 405427035,
#   'in_reply_to_user_id_str': '405427035',
#   'is_quote_status': False,
#   'lang': 'hi',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@ArvindKejriwal ये देख झूठे कंजड़ और चुल्लू भर पानी में डूब मर। https://t.co/17aUvC3dxb',
#   'truncated': False,
#   'user': {'can_media_tag': True,
#    'contributors_enabled': False,
#    'created_at': 'Mon Dec 05 15:47:15 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Sports Indian Athletes Cricketers and Commentators Leagues and Teams Sports News, TV and Scores Hindi Music Music',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 16,
#    'follow_request_sent': False,
#    'followed_by': False,
#    'followers_count': 7,
#    'following': False,
#    'friends_count': 106,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 805800713561391109,
#    'id_str': '805800713561391109',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'मुंबई, भारत',
#    'name': 'Mayank Sharma',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805800713561391109/1480953771',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'mayankveedwal',
#    'statuses_count': 15,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jan 10 12:42:41 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/0PC7y9EU9c',
#      'expanded_url': 'https://twitter.com/mayankveedwal/status/818800225762545664/photo/1',
#      'features': {'large': {'faces': []},
#       'medium': {'faces': []},
#       'orig': {'faces': []},
#       'small': {'faces': []}},
#      'id': 818800220557418496,
#      'id_str': '818800220557418496',
#      'indices': [16, 39],
#      'media_url': 'http://pbs.twimg.com/media/C1z2dmBWIAAJ1a7.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C1z2dmBWIAAJ1a7.jpg',
#      'sizes': {'large': {'h': 527, 'resize': 'fit', 'w': 720},
#       'medium': {'h': 527, 'resize': 'fit', 'w': 720},
#       'small': {'h': 498, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/0PC7y9EU9c'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 405427035,
#      'id_str': '405427035',
#      'indices': [0, 15],
#      'name': 'Arvind Kejriwal',
#      'screen_name': 'ArvindKejriwal'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/0PC7y9EU9c',
#      'expanded_url': 'https://twitter.com/mayankveedwal/status/818800225762545664/photo/1',
#      'features': {'large': {'faces': []},
#       'medium': {'faces': []},
#       'orig': {'faces': []},
#       'small': {'faces': []}},
#      'id': 818800220557418496,
#      'id_str': '818800220557418496',
#      'indices': [16, 39],
#      'media_url': 'http://pbs.twimg.com/media/C1z2dmBWIAAJ1a7.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C1z2dmBWIAAJ1a7.jpg',
#      'sizes': {'large': {'h': 527, 'resize': 'fit', 'w': 720},
#       'medium': {'h': 527, 'resize': 'fit', 'w': 720},
#       'small': {'h': 498, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/0PC7y9EU9c'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 818800225762545664,
#   'id_str': '818800225762545664',
#   'in_reply_to_screen_name': 'ArvindKejriwal',
#   'in_reply_to_status_id': 818762390279884803,
#   'in_reply_to_status_id_str': '818762390279884803',
#   'in_reply_to_user_id': 405427035,
#   'in_reply_to_user_id_str': '405427035',
#   'is_quote_status': False,
#   'lang': 'und',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@ArvindKejriwal https://t.co/0PC7y9EU9c',
#   'truncated': False,
#   'user': {'can_media_tag': True,
#    'contributors_enabled': False,
#    'created_at': 'Mon Dec 05 15:47:15 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Sports Indian Athletes Cricketers and Commentators Leagues and Teams Sports News, TV and Scores Hindi Music Music',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 16,
#    'follow_request_sent': False,
#    'followed_by': False,
#    'followers_count': 7,
#    'following': False,
#    'friends_count': 106,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 805800713561391109,
#    'id_str': '805800713561391109',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'मुंबई, भारत',
#    'name': 'Mayank Sharma',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805800713561391109/1480953771',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'mayankveedwal',
#    'statuses_count': 15,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jan 10 11:16:54 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/Tz4g0sl4gF',
#      'expanded_url': 'https://twitter.com/mayankveedwal/status/818778639399522304/photo/1',
#      'features': {'large': {'faces': []},
#       'medium': {'faces': []},
#       'orig': {'faces': []},
#       'small': {'faces': []}},
#      'id': 818778633733029888,
#      'id_str': '818778633733029888',
#      'indices': [16, 39],
#      'media_url': 'http://pbs.twimg.com/media/C1zi1E1WQAAHeqy.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C1zi1E1WQAAHeqy.jpg',
#      'sizes': {'large': {'h': 759, 'resize': 'fit', 'w': 480},
#       'medium': {'h': 759, 'resize': 'fit', 'w': 480},
#       'small': {'h': 680, 'resize': 'fit', 'w': 430},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/Tz4g0sl4gF'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 405427035,
#      'id_str': '405427035',
#      'indices': [0, 15],
#      'name': 'Arvind Kejriwal',
#      'screen_name': 'ArvindKejriwal'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/Tz4g0sl4gF',
#      'expanded_url': 'https://twitter.com/mayankveedwal/status/818778639399522304/photo/1',
#      'features': {'large': {'faces': []},
#       'medium': {'faces': []},
#       'orig': {'faces': []},
#       'small': {'faces': []}},
#      'id': 818778633733029888,
#      'id_str': '818778633733029888',
#      'indices': [16, 39],
#      'media_url': 'http://pbs.twimg.com/media/C1zi1E1WQAAHeqy.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C1zi1E1WQAAHeqy.jpg',
#      'sizes': {'large': {'h': 759, 'resize': 'fit', 'w': 480},
#       'medium': {'h': 759, 'resize': 'fit', 'w': 480},
#       'small': {'h': 680, 'resize': 'fit', 'w': 430},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/Tz4g0sl4gF'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 818778639399522304,
#   'id_str': '818778639399522304',
#   'in_reply_to_screen_name': 'ArvindKejriwal',
#   'in_reply_to_status_id': 818679781457858561,
#   'in_reply_to_status_id_str': '818679781457858561',
#   'in_reply_to_user_id': 405427035,
#   'in_reply_to_user_id_str': '405427035',
#   'is_quote_status': False,
#   'lang': 'und',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@ArvindKejriwal https://t.co/Tz4g0sl4gF',
#   'truncated': False,
#   'user': {'can_media_tag': True,
#    'contributors_enabled': False,
#    'created_at': 'Mon Dec 05 15:47:15 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Sports Indian Athletes Cricketers and Commentators Leagues and Teams Sports News, TV and Scores Hindi Music Music',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 16,
#    'follow_request_sent': False,
#    'followed_by': False,
#    'followers_count': 7,
#    'following': False,
#    'friends_count': 106,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 805800713561391109,
#    'id_str': '805800713561391109',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'मुंबई, भारत',
#    'name': 'Mayank Sharma',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805800713561391109/1480953771',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'mayankveedwal',
#    'statuses_count': 15,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jan 10 07:49:38 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 988858957,
#      'id_str': '988858957',
#      'indices': [0, 13],
#      'name': 'Preeti Sharma Menon',
#      'screen_name': 'PreetiSMenon'},
#     {'id': 405427035,
#      'id_str': '405427035',
#      'indices': [14, 29],
#      'name': 'Arvind Kejriwal',
#      'screen_name': 'ArvindKejriwal'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 818726477558644736,
#   'id_str': '818726477558644736',
#   'in_reply_to_screen_name': 'PreetiSMenon',
#   'in_reply_to_status_id': 818640613037981696,
#   'in_reply_to_status_id_str': '818640613037981696',
#   'in_reply_to_user_id': 988858957,
#   'in_reply_to_user_id_str': '988858957',
#   'is_quote_status': False,
#   'lang': 'hi',
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@PreetiSMenon @ArvindKejriwal जब केजरी खुजली अपने माँ बाप को रैली में इस्तेमाल करता है तब तेरे मुह में दही जम जाती है क्या?',
#   'truncated': False,
#   'user': {'can_media_tag': True,
#    'contributors_enabled': False,
#    'created_at': 'Mon Dec 05 15:47:15 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Sports Indian Athletes Cricketers and Commentators Leagues and Teams Sports News, TV and Scores Hindi Music Music',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 16,
#    'follow_request_sent': False,
#    'followed_by': False,
#    'followers_count': 7,
#    'following': False,
#    'friends_count': 106,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 805800713561391109,
#    'id_str': '805800713561391109',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'मुंबई, भारत',
#    'name': 'Mayank Sharma',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805800713561391109/1480953771',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'mayankveedwal',
#    'statuses_count': 15,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jan 10 07:48:03 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 141633175,
#      'id_str': '141633175',
#      'indices': [0, 15],
#      'name': 'Dr Kumar Vishvas',
#      'screen_name': 'DrKumarVishwas'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 818726080039227393,
#   'id_str': '818726080039227393',
#   'in_reply_to_screen_name': 'DrKumarVishwas',
#   'in_reply_to_status_id': 818683649134469120,
#   'in_reply_to_status_id_str': '818683649134469120',
#   'in_reply_to_user_id': 141633175,
#   'in_reply_to_user_id_str': '141633175',
#   'is_quote_status': False,
#   'lang': 'hi',
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@DrKumarVishwas तुमने भी तो ज़िन्दगी भर अकेले ही बोला है तुमने किसी को कभी सुना है? आपिये?',
#   'truncated': False,
#   'user': {'can_media_tag': True,
#    'contributors_enabled': False,
#    'created_at': 'Mon Dec 05 15:47:15 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Sports Indian Athletes Cricketers and Commentators Leagues and Teams Sports News, TV and Scores Hindi Music Music',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 16,
#    'follow_request_sent': False,
#    'followed_by': False,
#    'followers_count': 7,
#    'following': False,
#    'friends_count': 106,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 805800713561391109,
#    'id_str': '805800713561391109',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'मुंबई, भारत',
#    'name': 'Mayank Sharma',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805800713561391109/1480953771',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'mayankveedwal',
#    'statuses_count': 15,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jan 10 07:46:46 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 405427035,
#      'id_str': '405427035',
#      'indices': [0, 15],
#      'name': 'Arvind Kejriwal',
#      'screen_name': 'ArvindKejriwal'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 818725758986309632,
#   'id_str': '818725758986309632',
#   'in_reply_to_screen_name': 'ArvindKejriwal',
#   'in_reply_to_status_id': 818677534124408832,
#   'in_reply_to_status_id_str': '818677534124408832',
#   'in_reply_to_user_id': 405427035,
#   'in_reply_to_user_id_str': '405427035',
#   'is_quote_status': False,
#   'lang': 'hi',
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@ArvindKejriwal ना लेगा वो तेरा नाम। मर जायेगा तू मोदी मोदी करते करते पर वो तेरा नाम नहीं लेगा। बेकार में कोशिश मत कर मोदी की लुगाई।',
#   'truncated': False,
#   'user': {'can_media_tag': True,
#    'contributors_enabled': False,
#    'created_at': 'Mon Dec 05 15:47:15 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Sports Indian Athletes Cricketers and Commentators Leagues and Teams Sports News, TV and Scores Hindi Music Music',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 16,
#    'follow_request_sent': False,
#    'followed_by': False,
#    'followers_count': 7,
#    'following': False,
#    'friends_count': 106,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 805800713561391109,
#    'id_str': '805800713561391109',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'मुंबई, भारत',
#    'name': 'Mayank Sharma',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805800713561391109/1480953771',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'mayankveedwal',
#    'statuses_count': 15,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jan 10 07:45:16 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 405427035,
#      'id_str': '405427035',
#      'indices': [0, 15],
#      'name': 'Arvind Kejriwal',
#      'screen_name': 'ArvindKejriwal'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 818725381209489408,
#   'id_str': '818725381209489408',
#   'in_reply_to_screen_name': 'ArvindKejriwal',
#   'in_reply_to_status_id': 818679781457858561,
#   'in_reply_to_status_id_str': '818679781457858561',
#   'in_reply_to_user_id': 405427035,
#   'in_reply_to_user_id_str': '405427035',
#   'is_quote_status': False,
#   'lang': 'hi',
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@ArvindKejriwal तुझे हर बात में अपनी मरानी जरुरी है क्या मोदी की लुगाई।??? तू चाहे जो मर्ज़ी कर ले मोदी तेरा नाम नहीं लेगा। मर जा तू।',
#   'truncated': False,
#   'user': {'can_media_tag': True,
#    'contributors_enabled': False,
#    'created_at': 'Mon Dec 05 15:47:15 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Sports Indian Athletes Cricketers and Commentators Leagues and Teams Sports News, TV and Scores Hindi Music Music',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 16,
#    'follow_request_sent': False,
#    'followed_by': False,
#    'followers_count': 7,
#    'following': False,
#    'friends_count': 106,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 805800713561391109,
#    'id_str': '805800713561391109',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'मुंबई, भारत',
#    'name': 'Mayank Sharma',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805800713561391109/1480953771',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'mayankveedwal',
#    'statuses_count': 15,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jan 10 03:28:21 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/RIESFI3CEd',
#      'expanded_url': 'https://twitter.com/mayankveedwal/status/818660724339658752/photo/1',
#      'features': {'large': {'faces': [{'h': 50, 'w': 50, 'x': 52, 'y': 16}]},
#       'medium': {'faces': [{'h': 50, 'w': 50, 'x': 52, 'y': 16}]},
#       'orig': {'faces': [{'h': 50, 'w': 50, 'x': 52, 'y': 16}]},
#       'small': {'faces': [{'h': 47, 'w': 47, 'x': 49, 'y': 15}]}},
#      'id': 818660717523935232,
#      'id_str': '818660717523935232',
#      'indices': [16, 39],
#      'media_url': 'http://pbs.twimg.com/media/C1x3lcuUoAABp4Q.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C1x3lcuUoAABp4Q.jpg',
#      'sizes': {'large': {'h': 579, 'resize': 'fit', 'w': 720},
#       'medium': {'h': 579, 'resize': 'fit', 'w': 720},
#       'small': {'h': 547, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/RIESFI3CEd'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 405427035,
#      'id_str': '405427035',
#      'indices': [0, 15],
#      'name': 'Arvind Kejriwal',
#      'screen_name': 'ArvindKejriwal'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/RIESFI3CEd',
#      'expanded_url': 'https://twitter.com/mayankveedwal/status/818660724339658752/photo/1',
#      'features': {'large': {'faces': [{'h': 50, 'w': 50, 'x': 52, 'y': 16}]},
#       'medium': {'faces': [{'h': 50, 'w': 50, 'x': 52, 'y': 16}]},
#       'orig': {'faces': [{'h': 50, 'w': 50, 'x': 52, 'y': 16}]},
#       'small': {'faces': [{'h': 47, 'w': 47, 'x': 49, 'y': 15}]}},
#      'id': 818660717523935232,
#      'id_str': '818660717523935232',
#      'indices': [16, 39],
#      'media_url': 'http://pbs.twimg.com/media/C1x3lcuUoAABp4Q.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C1x3lcuUoAABp4Q.jpg',
#      'sizes': {'large': {'h': 579, 'resize': 'fit', 'w': 720},
#       'medium': {'h': 579, 'resize': 'fit', 'w': 720},
#       'small': {'h': 547, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/RIESFI3CEd'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 818660724339658752,
#   'id_str': '818660724339658752',
#   'in_reply_to_screen_name': 'ArvindKejriwal',
#   'in_reply_to_status_id': 818452335575777280,
#   'in_reply_to_status_id_str': '818452335575777280',
#   'in_reply_to_user_id': 405427035,
#   'in_reply_to_user_id_str': '405427035',
#   'is_quote_status': False,
#   'lang': 'und',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@ArvindKejriwal https://t.co/RIESFI3CEd',
#   'truncated': False,
#   'user': {'can_media_tag': True,
#    'contributors_enabled': False,
#    'created_at': 'Mon Dec 05 15:47:15 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Sports Indian Athletes Cricketers and Commentators Leagues and Teams Sports News, TV and Scores Hindi Music Music',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 16,
#    'follow_request_sent': False,
#    'followed_by': False,
#    'followers_count': 7,
#    'following': False,
#    'friends_count': 106,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 805800713561391109,
#    'id_str': '805800713561391109',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'मुंबई, भारत',
#    'name': 'Mayank Sharma',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805800713561391109/1480953771',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'mayankveedwal',
#    'statuses_count': 15,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 06 11:49:33 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 405427035,
#      'id_str': '405427035',
#      'indices': [0, 15],
#      'name': 'Arvind Kejriwal',
#      'screen_name': 'ArvindKejriwal'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 817337306541654018,
#   'id_str': '817337306541654018',
#   'in_reply_to_screen_name': 'ArvindKejriwal',
#   'in_reply_to_status_id': 816853408950861828,
#   'in_reply_to_status_id_str': '816853408950861828',
#   'in_reply_to_user_id': 405427035,
#   'in_reply_to_user_id_str': '405427035',
#   'is_quote_status': False,
#   'lang': 'hi',
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@ArvindKejriwal हाहाहाहा अबे नौटंकी मोदी तेरे जैसे टट पंजू से डरेगा? औकात क्या है तेरी एक छोटे से राज्य के मेयर बराबर औकात के नौटंकी cm?',
#   'truncated': False,
#   'user': {'can_media_tag': True,
#    'contributors_enabled': False,
#    'created_at': 'Mon Dec 05 15:47:15 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Sports Indian Athletes Cricketers and Commentators Leagues and Teams Sports News, TV and Scores Hindi Music Music',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 16,
#    'follow_request_sent': False,
#    'followed_by': False,
#    'followers_count': 7,
#    'following': False,
#    'friends_count': 106,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 805800713561391109,
#    'id_str': '805800713561391109',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'मुंबई, भारत',
#    'name': 'Mayank Sharma',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805800713561391109/1480953771',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'mayankveedwal',
#    'statuses_count': 15,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 06 11:48:10 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 405427035,
#      'id_str': '405427035',
#      'indices': [0, 15],
#      'name': 'Arvind Kejriwal',
#      'screen_name': 'ArvindKejriwal'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 817336954534723585,
#   'id_str': '817336954534723585',
#   'in_reply_to_screen_name': 'ArvindKejriwal',
#   'in_reply_to_status_id': 816837361493417984,
#   'in_reply_to_status_id_str': '816837361493417984',
#   'in_reply_to_user_id': 405427035,
#   'in_reply_to_user_id_str': '405427035',
#   'is_quote_status': False,
#   'lang': 'hi',
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@ArvindKejriwal अरे वो शीला दीक्षित को जिस जेल में डाल दिया तूने उसी में मजीठिया को भी डलवा दे। मोदी तो तेरे सपनो में भी आता होगा नौटंकी।',
#   'truncated': False,
#   'user': {'can_media_tag': True,
#    'contributors_enabled': False,
#    'created_at': 'Mon Dec 05 15:47:15 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Sports Indian Athletes Cricketers and Commentators Leagues and Teams Sports News, TV and Scores Hindi Music Music',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 16,
#    'follow_request_sent': False,
#    'followed_by': False,
#    'followers_count': 7,
#    'following': False,
#    'friends_count': 106,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 805800713561391109,
#    'id_str': '805800713561391109',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'मुंबई, भारत',
#    'name': 'Mayank Sharma',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805800713561391109/1480953771',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'mayankveedwal',
#    'statuses_count': 15,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 06 11:46:30 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 135842711,
#      'id_str': '135842711',
#      'indices': [14, 30],
#      'name': 'Lalit Gohate',
#      'screen_name': 'lalitgohate1411'},
#     {'id': 729510151590453248,
#      'id_str': '729510151590453248',
#      'indices': [31, 46],
#      'name': 'I Support AAP',
#      'screen_name': 'amitkumar13557'},
#     {'id': 405427035,
#      'id_str': '405427035',
#      'indices': [47, 62],
#      'name': 'Arvind Kejriwal',
#      'screen_name': 'ArvindKejriwal'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 817336538895884289,
#   'id_str': '817336538895884289',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'hi',
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@NadimRamAli_ @lalitgohate1411 @amitkumar13557 @ArvindKejriwal मोदी मोदी मोदी केजरीवाल को मोदी नाम जपने के लिए वोट नहीं दिया था जनता ने।',
#   'truncated': False,
#   'user': {'can_media_tag': True,
#    'contributors_enabled': False,
#    'created_at': 'Mon Dec 05 15:47:15 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Sports Indian Athletes Cricketers and Commentators Leagues and Teams Sports News, TV and Scores Hindi Music Music',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 16,
#    'follow_request_sent': False,
#    'followed_by': False,
#    'followers_count': 7,
#    'following': False,
#    'friends_count': 106,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 805800713561391109,
#    'id_str': '805800713561391109',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'मुंबई, भारत',
#    'name': 'Mayank Sharma',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805800713561391109/1480953771',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'mayankveedwal',
#    'statuses_count': 15,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Dec 31 13:54:49 +0000 2016',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/43AsXCvxpE',
#      'expanded_url': 'https://twitter.com/mayankveedwal/status/815194502860152832/photo/1',
#      'features': {'large': {'faces': [{'h': 75, 'w': 75, 'x': 202, 'y': 74}]},
#       'medium': {'faces': [{'h': 75, 'w': 75, 'x': 202, 'y': 74}]},
#       'orig': {'faces': [{'h': 75, 'w': 75, 'x': 202, 'y': 74}]},
#       'small': {'faces': [{'h': 70, 'w': 70, 'x': 190, 'y': 69}]}},
#      'id': 815194497449500672,
#      'id_str': '815194497449500672',
#      'indices': [72, 95],
#      'media_url': 'http://pbs.twimg.com/media/C1AnE4tUoAAiscC.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C1AnE4tUoAAiscC.jpg',
#      'sizes': {'large': {'h': 403, 'resize': 'fit', 'w': 720},
#       'medium': {'h': 403, 'resize': 'fit', 'w': 720},
#       'small': {'h': 381, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/43AsXCvxpE'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 405427035,
#      'id_str': '405427035',
#      'indices': [0, 15],
#      'name': 'Arvind Kejriwal',
#      'screen_name': 'ArvindKejriwal'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/43AsXCvxpE',
#      'expanded_url': 'https://twitter.com/mayankveedwal/status/815194502860152832/photo/1',
#      'features': {'large': {'faces': [{'h': 75, 'w': 75, 'x': 202, 'y': 74}]},
#       'medium': {'faces': [{'h': 75, 'w': 75, 'x': 202, 'y': 74}]},
#       'orig': {'faces': [{'h': 75, 'w': 75, 'x': 202, 'y': 74}]},
#       'small': {'faces': [{'h': 70, 'w': 70, 'x': 190, 'y': 69}]}},
#      'id': 815194497449500672,
#      'id_str': '815194497449500672',
#      'indices': [72, 95],
#      'media_url': 'http://pbs.twimg.com/media/C1AnE4tUoAAiscC.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C1AnE4tUoAAiscC.jpg',
#      'sizes': {'large': {'h': 403, 'resize': 'fit', 'w': 720},
#       'medium': {'h': 403, 'resize': 'fit', 'w': 720},
#       'small': {'h': 381, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/43AsXCvxpE'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 815194502860152832,
#   'id_str': '815194502860152832',
#   'in_reply_to_screen_name': 'ArvindKejriwal',
#   'in_reply_to_status_id': 815152460209659904,
#   'in_reply_to_status_id_str': '815152460209659904',
#   'in_reply_to_user_id': 405427035,
#   'in_reply_to_user_id_str': '405427035',
#   'is_quote_status': False,
#   'lang': 'hi',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@ArvindKejriwal टीवी पर मोदी जी का "देश के नाम संदेश " सुनने से पहले ।👇 https://t.co/43AsXCvxpE',
#   'truncated': False,
#   'user': {'can_media_tag': True,
#    'contributors_enabled': False,
#    'created_at': 'Mon Dec 05 15:47:15 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Sports Indian Athletes Cricketers and Commentators Leagues and Teams Sports News, TV and Scores Hindi Music Music',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 16,
#    'follow_request_sent': False,
#    'followed_by': False,
#    'followers_count': 7,
#    'following': False,
#    'friends_count': 106,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 805800713561391109,
#    'id_str': '805800713561391109',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'मुंबई, भारत',
#    'name': 'Mayank Sharma',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805800713561391109/1480953771',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'mayankveedwal',
#    'statuses_count': 15,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Dec 31 12:50:07 +0000 2016',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 405427035,
#      'id_str': '405427035',
#      'indices': [0, 15],
#      'name': 'Arvind Kejriwal',
#      'screen_name': 'ArvindKejriwal'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 815178219393400833,
#   'id_str': '815178219393400833',
#   'in_reply_to_screen_name': 'ArvindKejriwal',
#   'in_reply_to_status_id': 815152460209659904,
#   'in_reply_to_status_id_str': '815152460209659904',
#   'in_reply_to_user_id': 405427035,
#   'in_reply_to_user_id_str': '405427035',
#   'is_quote_status': False,
#   'lang': 'hi',
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@ArvindKejriwal तेरे तो सपने में भी मोदी आता होगा। सुना है राशन कार्ड बनायेगा तू आज रात किसी का।',
#   'truncated': False,
#   'user': {'can_media_tag': True,
#    'contributors_enabled': False,
#    'created_at': 'Mon Dec 05 15:47:15 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Sports Indian Athletes Cricketers and Commentators Leagues and Teams Sports News, TV and Scores Hindi Music Music',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 16,
#    'follow_request_sent': False,
#    'followed_by': False,
#    'followers_count': 7,
#    'following': False,
#    'friends_count': 106,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 805800713561391109,
#    'id_str': '805800713561391109',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'मुंबई, भारत',
#    'name': 'Mayank Sharma',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805800713561391109/1480953771',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'mayankveedwal',
#    'statuses_count': 15,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Dec 21 08:02:10 +0000 2016',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/WJNYW5R2B5',
#      'expanded_url': 'https://twitter.com/mayankveedwal/status/811481877026656256/photo/1',
#      'features': {'large': {'faces': [{'h': 51, 'w': 51, 'x': 89, 'y': 558},
#         {'h': 51, 'w': 51, 'x': 54, 'y': 804},
#         {'h': 67, 'w': 67, 'x': 95, 'y': 85}]},
#       'medium': {'faces': [{'h': 51, 'w': 51, 'x': 89, 'y': 558},
#         {'h': 51, 'w': 51, 'x': 54, 'y': 804},
#         {'h': 67, 'w': 67, 'x': 95, 'y': 85}]},
#       'orig': {'faces': [{'h': 51, 'w': 51, 'x': 89, 'y': 558},
#         {'h': 51, 'w': 51, 'x': 54, 'y': 804},
#         {'h': 67, 'w': 67, 'x': 95, 'y': 85}]},
#       'small': {'faces': [{'h': 36, 'w': 36, 'x': 63, 'y': 395},
#         {'h': 36, 'w': 36, 'x': 38, 'y': 569},
#         {'h': 47, 'w': 47, 'x': 67, 'y': 60}]}},
#      'id': 811481853609836544,
#      'id_str': '811481853609836544',
#      'indices': [16, 39],
#      'media_url': 'http://pbs.twimg.com/media/C0L2ckoXAAAgCW9.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C0L2ckoXAAAgCW9.jpg',
#      'sizes': {'large': {'h': 960, 'resize': 'fit', 'w': 720},
#       'medium': {'h': 960, 'resize': 'fit', 'w': 720},
#       'small': {'h': 680, 'resize': 'fit', 'w': 510},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/WJNYW5R2B5'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 405427035,
#      'id_str': '405427035',
#      'indices': [0, 15],
#      'name': 'Arvind Kejriwal',
#      'screen_name': 'ArvindKejriwal'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/WJNYW5R2B5',
#      'expanded_url': 'https://twitter.com/mayankveedwal/status/811481877026656256/photo/1',
#      'features': {'large': {'faces': [{'h': 51, 'w': 51, 'x': 89, 'y': 558},
#         {'h': 51, 'w': 51, 'x': 54, 'y': 804},
#         {'h': 67, 'w': 67, 'x': 95, 'y': 85}]},
#       'medium': {'faces': [{'h': 51, 'w': 51, 'x': 89, 'y': 558},
#         {'h': 51, 'w': 51, 'x': 54, 'y': 804},
#         {'h': 67, 'w': 67, 'x': 95, 'y': 85}]},
#       'orig': {'faces': [{'h': 51, 'w': 51, 'x': 89, 'y': 558},
#         {'h': 51, 'w': 51, 'x': 54, 'y': 804},
#         {'h': 67, 'w': 67, 'x': 95, 'y': 85}]},
#       'small': {'faces': [{'h': 36, 'w': 36, 'x': 63, 'y': 395},
#         {'h': 36, 'w': 36, 'x': 38, 'y': 569},
#         {'h': 47, 'w': 47, 'x': 67, 'y': 60}]}},
#      'id': 811481853609836544,
#      'id_str': '811481853609836544',
#      'indices': [16, 39],
#      'media_url': 'http://pbs.twimg.com/media/C0L2ckoXAAAgCW9.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C0L2ckoXAAAgCW9.jpg',
#      'sizes': {'large': {'h': 960, 'resize': 'fit', 'w': 720},
#       'medium': {'h': 960, 'resize': 'fit', 'w': 720},
#       'small': {'h': 680, 'resize': 'fit', 'w': 510},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/WJNYW5R2B5'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 811481877026656256,
#   'id_str': '811481877026656256',
#   'in_reply_to_screen_name': 'ArvindKejriwal',
#   'in_reply_to_status_id': 811434809582944256,
#   'in_reply_to_status_id_str': '811434809582944256',
#   'in_reply_to_user_id': 405427035,
#   'in_reply_to_user_id_str': '405427035',
#   'is_quote_status': False,
#   'lang': 'und',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@ArvindKejriwal https://t.co/WJNYW5R2B5',
#   'truncated': False,
#   'user': {'can_media_tag': True,
#    'contributors_enabled': False,
#    'created_at': 'Mon Dec 05 15:47:15 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Sports Indian Athletes Cricketers and Commentators Leagues and Teams Sports News, TV and Scores Hindi Music Music',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 16,
#    'follow_request_sent': False,
#    'followed_by': False,
#    'followers_count': 7,
#    'following': False,
#    'friends_count': 106,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 805800713561391109,
#    'id_str': '805800713561391109',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'मुंबई, भारत',
#    'name': 'Mayank Sharma',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805800713561391109/1480953771',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805804642772750337/Sm3LtpVJ_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'mayankveedwal',
#    'statuses_count': 15,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}}]

# %% [markdown]
# # Exercises

# %% [markdown]
# * find out how to save files to your own machine using urllib
# * find out how to convert json dumps to pandas dataframes
